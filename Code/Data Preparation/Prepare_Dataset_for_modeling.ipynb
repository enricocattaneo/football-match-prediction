# %% [markdown]
# # **Data Transformation and Preparation**

# %% [markdown]
# ##### Initial Setup

# %% [markdown]
# Imports

# %%
# Packages
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
from tqdm.notebook import tqdm
import dateutil.parser
from geopy import distance
import re
from itertools import product
import warnings
# Pandas options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# Static Import & Data Types

# %%
# Import data
static = pd.read_csv('../../Data/From_Preparation/match_cleaned.csv', low_memory = False)
# Set Fixtures' id as index
static.set_index('id', inplace=True)
# Change data types
float_columns = ['weather_report_pressure', 'weather_report_temp_celsius', 'weather_report_windspeed(m/s)', 'home_passes_percentage', 'away_passes_percentage'] # columns that will be floats
static[float_columns] = static[float_columns].astype('float64')       
m = static.select_dtypes(np.number).loc[:, ~static.select_dtypes(np.number).columns.isin(float_columns)]
static[m.columns]= m.round().astype('Int64')
# Convert dates to datetime format
static['time_starting_at_date_time'] = pd.to_datetime(static['time_starting_at_date_time'], infer_datetime_format=True)
date_dates = ['time_starting_at_date', 'round_start', 'round_end', 'homecoach_birthdate', 'awaycoach_birthdate']
for date_col in date_dates:
    static[date_col] = pd.to_datetime(static[date_col], format = '%Y-%m-%d')
# Sort values
static = static.sort_values(by='time_starting_at_date_time')
static.head()
# Out:
#          league_id  season_id  stage_id  venue_id  referee_id  home_id  \
# id
# 1062005          2       5321     10023      5732        <NA>     8643
# 1067032          5       5337     10210      7361        <NA>     7345
# 1067052          5       5337     10210      3653        <NA>     5500
# 1067071          5       5337     10210      2536        <NA>     6497
# 1067093          5       5337     10210      3627        <NA>     5495
#
#          away_id  winner_team_id  commentaries  attendance  \
# id
# 1062005      579             579             0        <NA>
# 1067032      589               0             0        <NA>
# 1067052     6213            5500             0        <NA>
# 1067071      890             890             0        <NA>
# 1067093      734            5495             0        <NA>
#
#         formations_home_formation formations_away_formation  \
# id
# 1062005                       NaN                       NaN
# 1067032                       NaN                       NaN
# 1067052                       NaN                       NaN
# 1067071                       NaN                       NaN
# 1067093                       NaN                       NaN
#
#          scores_home_score  scores_away_score scores_ht_score scores_ft_score  \
# id
# 1062005                  1                  2             1-1             1-2
# 1067032                  0                  0             0-0             0-0
# 1067052                  2                  0             1-0             2-0
# 1067071                  0                  1             0-0             0-1
# 1067093                  1                  0             0-0             1-0
#
#         scores_et_score scores_ps_score time_starting_at_date_time  \
# id
# 1062005             NaN             NaN        2015-07-01 20:00:00
# 1067032             NaN             NaN        2015-07-02 14:00:00
# 1067052             NaN             NaN        2015-07-02 15:30:00
# 1067071             NaN             NaN        2015-07-02 17:00:00
# 1067093             NaN             NaN        2015-07-02 17:00:00
#
#         time_starting_at_date time_starting_at_timezone  time_minute  \
# id
# 1062005            2015-07-01               Europe/Rome           90
# 1067032            2015-07-02               Europe/Rome           90
# 1067052            2015-07-02               Europe/Rome           90
# 1067071            2015-07-02               Europe/Rome           90
# 1067093            2015-07-02               Europe/Rome           90
#
#          standings_home_position  standings_away_position  home_name  \
# id
# 1062005                     <NA>                     <NA>        B36
# 1067032                     <NA>                     <NA>   Ordabasy
# 1067052                     <NA>                     <NA>     Shirak
# 1067071                     <NA>                     <NA>  Pakruojis
# 1067093                     <NA>                     <NA>  Alashkert
#
#         home_twitter  home_country_id  home_founded  home_venue_id  \
# id
# 1062005          NaN             2154          1936           5605
# 1067032          NaN             2427          1998           4763
# 1067052          NaN              919          1958           3632
# 1067071          NaN             2079             0         338658
# 1067093          NaN              919          1990         260195
#
#                      away_name away_twitter  away_country_id  away_founded  \
# id
# 1062005         The New Saints          NaN              515          1959
# 1067032       Beitar Jerusalem          NaN              802          1936
# 1067052               Zrinjski          NaN              507          1905
# 1067071  Jagiellonia Białystok          NaN                2          1927
# 1067093          St. Johnstone          NaN             1161          1885
#
#          away_venue_id        league_type  league_country_id  \
# id
# 1062005            114  cup_international                 41
# 1067032             35  cup_international                 41
# 1067052           4032  cup_international                 41
# 1067071            316  cup_international                 41
# 1067093            219  cup_international                 41
#
#               league_name  league_is_cup season_name  round_name round_start  \
# id
# 1062005  Champions League              1   2015/2016        <NA>         NaT
# 1067032     Europa League              1   2015/2016        <NA>         NaT
# 1067052     Europa League              1   2015/2016        <NA>         NaT
# 1067071     Europa League              1   2015/2016        <NA>         NaT
# 1067093     Europa League              1   2015/2016        <NA>         NaT
#
#         round_end                                     venue_name  \
# id
# 1062005       NaT                                     Tórsvøllur
# 1067032       NaT            Stadion im. Qajimuqan Mungaytpasuli
# 1067052       NaT                                         Gyumri
# 1067071       NaT              Šiaulių m. savivaldybes stadionas
# 1067093       NaT  Vazgen Sargsyan anvan Hanrapetakan Marzadasht
#
#          venue_surface_isgrass venue_city  venue_capacity  \
# id
# 1062005                      1   Tórshavn           81044
# 1067032                      1     Astana           12343
# 1067052                   <NA>     Gyumri            <NA>
# 1067071                      1   Šiauliai            4000
# 1067093                      1    Yerevan           53849
#
#              venue_coordinates referee_fullname  homecoach_coach_id  \
# id
# 1062005  (40.453068,-3.688354)              NaN              466794
# 1067032    (51.16159,71.39925)              NaN             1552713
# 1067052    (40.80272,43.84833)              NaN              462696
# 1067071  (55.936667,23.295556)              NaN            18922742
# 1067093  (40.180403,44.494967)              NaN              462666
#
#          homecoach_country_id   homecoach_fullname homecoach_nationality  \
# id
# 1062005                  2154      Eyðun Klakstein         Faroe Islands
# 1067032                   227       Viktor Kumykov                Russia
# 1067052                   919  Vardan Bichakhchyan               Armenia
# 1067071                    86     Mykola Trubachov               Ukraine
# 1067093                   919  Abraham Khashmanyan               Armenia
#
#         homecoach_birthdate homecoach_birthcountry  awaycoach_coach_id  \
# id
# 1062005          1972-11-28          Faroe Islands              455867
# 1067032          1963-05-12                 Russia             3188090
# 1067052          1977-10-09                Armenia             1477271
# 1067071          1957-05-20                Ukraine              456327
# 1067093          1967-11-11                Armenia              896466
#
#          awaycoach_country_id awaycoach_fullname awaycoach_nationality  \
# id
# 1062005                   462     Craig Harrison               England
# 1067032                   296    Slobodan Drapić                Serbia
# 1067052                   296    Vinko Marinović                Serbia
# 1067071                     2    Michal Probierz                Poland
# 1067093                   491       Tommy Wright      Northern Ireland
#
#         awaycoach_birthdate awaycoach_birthcountry weather_report_code  \
# id
# 1062005          1977-11-10                England                 NaN
# 1067032          1965-02-28                 Serbia                 NaN
# 1067052          1971-03-03                Austria                 NaN
# 1067071          1972-09-24                 Poland                 NaN
# 1067093          1963-08-29       Northern Ireland                 NaN
#
#         weather_report_type  weather_report_windspeed(m/s)  \
# id
# 1062005                 NaN                            NaN
# 1067032                 NaN                            NaN
# 1067052                 NaN                            NaN
# 1067071                 NaN                            NaN
# 1067093                 NaN                            NaN
#
#          weather_report_wind_degree  weather_report_clouds(%)  \
# id
# 1062005                        <NA>                      <NA>
# 1067032                        <NA>                      <NA>
# 1067052                        <NA>                      <NA>
# 1067071                        <NA>                      <NA>
# 1067093                        <NA>                      <NA>
#
#          weather_report_humidity(%) colors_home_color colors_away_color  \
# id
# 1062005                        <NA>           #F0F0F0           #2B72DE
# 1067032                        <NA>           #F0F0F0           #FBED32
# 1067052                        <NA>               NaN           #002B87
# 1067071                        <NA>               NaN               NaN
# 1067093                        <NA>           #F0F0F0           #0046A8
#
#          weather_report_pressure  home_shots_total  home_shots_ongoal  \
# id
# 1062005                      NaN              <NA>               <NA>
# 1067032                      NaN              <NA>               <NA>
# 1067052                      NaN              <NA>               <NA>
# 1067071                      NaN              <NA>               <NA>
# 1067093                      NaN              <NA>               <NA>
#
#          home_shots_offgoal  home_shots_blocked  home_shots_insidebox  \
# id
# 1062005                <NA>                <NA>                  <NA>
# 1067032                <NA>                <NA>                  <NA>
# 1067052                <NA>                <NA>                  <NA>
# 1067071                <NA>                <NA>                  <NA>
# 1067093                <NA>                <NA>                  <NA>
#
#          home_shots_outsidebox  home_fouls  home_corners  home_offsides  \
# id
# 1062005                   <NA>        <NA>             0              0
# 1067032                   <NA>        <NA>             0              0
# 1067052                   <NA>        <NA>             0              0
# 1067071                   <NA>        <NA>             0              0
# 1067093                   <NA>        <NA>             0              0
#
#          home_possessiontime  home_yellowcards  home_redcards  \
# id
# 1062005                 <NA>                 0              0
# 1067032                 <NA>                 0              0
# 1067052                 <NA>                 0              0
# 1067071                 <NA>                 0              0
# 1067093                 <NA>                 0              0
#
#          home_yellowredcards  home_saves  home_tackles  away_shots_total  \
# id
# 1062005                    0        <NA>          <NA>              <NA>
# 1067032                    0        <NA>          <NA>              <NA>
# 1067052                    0        <NA>          <NA>              <NA>
# 1067071                    0        <NA>          <NA>              <NA>
# 1067093                    0        <NA>          <NA>              <NA>
#
#          away_shots_ongoal  away_shots_offgoal  away_shots_blocked  \
# id
# 1062005               <NA>                <NA>                <NA>
# 1067032               <NA>                <NA>                <NA>
# 1067052               <NA>                <NA>                <NA>
# 1067071               <NA>                <NA>                <NA>
# 1067093               <NA>                <NA>                <NA>
#
#          away_shots_insidebox  away_shots_outsidebox  away_fouls  \
# id
# 1062005                  <NA>                   <NA>        <NA>
# 1067032                  <NA>                   <NA>        <NA>
# 1067052                  <NA>                   <NA>        <NA>
# 1067071                  <NA>                   <NA>        <NA>
# 1067093                  <NA>                   <NA>        <NA>
#
#          away_corners  away_offsides  away_possessiontime  away_yellowcards  \
# id
# 1062005             0              0                 <NA>                 0
# 1067032             0              0                 <NA>                 0
# 1067052             0              0                 <NA>                 0
# 1067071             0              0                 <NA>                 0
# 1067093             0              0                 <NA>                 0
#
#          away_redcards  away_yellowredcards  away_saves  away_tackles  \
# id
# 1062005              0                    0        <NA>          <NA>
# 1067032              0                    0        <NA>          <NA>
# 1067052              0                    0        <NA>          <NA>
# 1067071              0                    0        <NA>          <NA>
# 1067093              0                    0        <NA>          <NA>
#
#          home_passes_total  home_passes_accurate  home_passes_percentage  \
# id
# 1062005               <NA>                  <NA>                     NaN
# 1067032               <NA>                  <NA>                     NaN
# 1067052               <NA>                  <NA>                     NaN
# 1067071               <NA>                  <NA>                     NaN
# 1067093               <NA>                  <NA>                     NaN
#
#          away_passes_total  away_passes_accurate  away_passes_percentage  \
# id
# 1062005               <NA>                  <NA>                     NaN
# 1067032               <NA>                  <NA>                     NaN
# 1067052               <NA>                  <NA>                     NaN
# 1067071               <NA>                  <NA>                     NaN
# 1067093               <NA>                  <NA>                     NaN
#
#          home_attacks_attacks  home_attacks_dangerous_attacks  \
# id
# 1062005                  <NA>                            <NA>
# 1067032                  <NA>                            <NA>
# 1067052                  <NA>                            <NA>
# 1067071                  <NA>                            <NA>
# 1067093                  <NA>                            <NA>
#
#          away_attacks_attacks  away_attacks_dangerous_attacks weather_lat_lon  \
# id
# 1062005                  <NA>                            <NA>      (nan, nan)
# 1067032                  <NA>                            <NA>      (nan, nan)
# 1067052                  <NA>                            <NA>      (nan, nan)
# 1067071                  <NA>                            <NA>      (nan, nan)
# 1067093                  <NA>                            <NA>      (nan, nan)
#
#          weather_report_temp_celsius  result  goal_diff
# id
# 1062005                          NaN       2         -1
# 1067032                          NaN       0          0
# 1067052                          NaN       1          2
# 1067071                          NaN       2         -1
# 1067093                          NaN       1          1

# %% [markdown]
# ## *Standings Data*

# %% [markdown]
# Prepare static dataframe

# %%
# Reset static index
static = static.reset_index()
static_leagues = static.loc[static['league_is_cup'] == 0, :] # Interest in attributes only for leagues' matches 
static_cups = static.loc[~(static['league_is_cup'] == 0), :]
# Consider for each match the standings before the game started
static_leagues['ROUND'] = static_leagues['round_name'] - 1

# %% [markdown]
# Import tables

# %%
# Import tables
table_total = pd.read_csv('../../Data/From_Collection/Standings_output/tables_FULL.csv')
table_home = pd.read_csv('../../Data/From_Collection/Standings_output/tables_HOME.csv')
table_away = pd.read_csv('../../Data/From_Collection/Standings_output/tables_AWAY.csv')
# Create DataFrames for Full Time, 1st Half, and 2nd Half results for table_total (containing the total standings)
table_FT_TO = table_total[(table_total['Type'] == 'FT')]
table_1H_TO = table_total[(table_total['Type'] == '1H')]
table_2H_TO = table_total[(table_total['Type'] == '2H')]
# Create DataFrames for Full Time, 1st Half, and 2nd Half results for table_home (containing only the home standings)
table_FT_OH = table_home[(table_home['Type'] == 'FT')]
table_1H_OH = table_home[(table_home['Type'] == '1H')]
table_2H_OH = table_home[(table_home['Type'] == '2H')]
# Create DataFrames for Full Time, 1st Half, and 2nd Half results for table_away (containing only the away standings)
table_FT_OA = table_away[(table_away['Type'] == 'FT')]
table_1H_OA = table_away[(table_away['Type'] == '1H')]
table_2H_OA = table_away[(table_away['Type'] == '2H')]

# %% [markdown]
# Merge static_leagues with multiple tables & create new features

# %%
# Dictionary connecting suffixes with tables
suffixes_tables = {'_FT_TO_H': table_FT_TO, '_1H_TO_H': table_1H_TO, '_2H_TO_H': table_2H_TO, '_FT_TO_A': table_FT_TO, '_1H_TO_A': table_1H_TO, '_2H_TO_A': table_2H_TO, '_FT_OH_H': table_FT_OH, '_1H_OH_H': table_1H_OH, '_2H_OH_H': table_2H_OH, '_FT_OA_A': table_FT_OA, '_1H_OA_A': table_1H_OA, '_2H_OA_A': table_2H_OA}
# Dictionary with new columns' names as keys and old columns' names as values 
new_cols_names = {'W%': 'Won', 'D%': 'Drawn', 'L%': 'Lost', 'GFxGame': 'GF', 'GAxGame': 'GA', 'GDxGame': 'GD', 'PointsxGame': 'Points'}
features_names_links = {}
# Loop over suffixes_tables items
for suffix, table in suffixes_tables.items():
    # A table could be either for home teams or away teams, with different keys used in the merger
    if re.search('_H$', suffix): left_keys_merge = ['season_id', 'home_name', 'ROUND']
    elif re.search('_A$', suffix): left_keys_merge = ['season_id', 'away_name', 'ROUND']
    else: raise Exception('Suffix neither for home or away!') 
    # Format table columns and columns' names
    table.loc[:, 'round_name'] = table.loc[:, 'round_name'].astype(int)
    table = table.add_suffix(suffix)
    # Merge static data with table
    static_leagues = static_leagues.merge(right=table, how='left', left_on=left_keys_merge, \
        right_on=['season_id' + suffix, 'Team' + suffix, 'round_name' + suffix])
    # Create new columns for each table by looping on the new_cols_names dictionary
    for new_name, old_name in new_cols_names.items():
        static_leagues[new_name + suffix] = static_leagues[old_name + suffix] / static_leagues['Played' + suffix]
        # Create dictionary linking old and newly generated features for later use
        features_names_links[old_name + suffix] = new_name + suffix
# Out:
# /Library/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`

# %% [markdown]
# Fill empty rounds data using previous observations

# %%
static_leagues = static_leagues.set_index('id')
fill_table_cols = static_leagues.columns[-241:].tolist()
for col in tqdm(fill_table_cols):
    if re.search('_H$', col): team = 'home_name'
    elif re.search('_A$', col): team = 'away_name'
    for i in static_leagues.index:
        if pd.isnull(static_leagues.loc[i, col]):
            datee = static_leagues.loc[i, 'time_starting_at_date']
            namee = static_leagues.loc[i, team]
            try: 
                maxx = max(static_leagues.loc[(static_leagues['time_starting_at_date'] < datee) & (static_leagues[team] == namee), 'time_starting_at_date'])
                f_i = (static_leagues.index[(static_leagues['time_starting_at_date'] == maxx) & (static_leagues[team] == namee)]).tolist()
                static_leagues.loc[i, col] = static_leagues.loc[f_i[0], col]
            except:
                static_leagues.loc[i, col] = np.nan
# Out:
#   0%|          | 0/241 [00:00<?, ?it/s]

# %%
static_leagues = static_leagues.loc[static_leagues['season_name'] != '2015/2016', :]

# %% [markdown]
# Fill empty rounds data using quantiles (for newly promoted teams)

# %%
def fillna_random_quantiles_group(df, column, quantile_range_lower, quantile_range_upper):
    """This function fills NAs in a datframe's specified column using random values contained in the given quantile range (between the lower and upper bound).
    df: dataframe
    column: column with NAs to fill 
    quantile_range_lower: lower bound for the qauntile range
    quantile_range_upper: upper bound for the qauntile range
    """
    # Get the n=20 quantiles inside the provided quantile range
    quantiles = {df[column].quantile(q=i) for i in np.linspace(quantile_range_lower, quantile_range_upper, 20)}
    # Fill NAs with a randomly chosen quantile value
    mask = df[column].isnull()
    samples = np.random.choice(list(quantiles), size=mask.sum())
    df.loc[mask, column] = samples
    return df

# %%
# Dictionary of columns' filters and quantile range indications (giving always 20% worst values to newly promoted teams)
reg_fill_by_quantile = {'^W%_': 'l', '^D%_': 'l', '^L%_': 'h', 'GFxGame_': 'l', 'GAxGame_': 'h', 'GDxGame_': 'l', 'PointsxGame_': 'l', 'rank_': 'h'}
for reg, value in reg_fill_by_quantile.items():
    quantile_low, quantile_up = (0, 0.20) if value == 'l' else (0.80, 1) # translate from value to quantile range
    for col in static_leagues.filter(regex=reg).columns: # filter columns using regex 
        static_leagues = fillna_random_quantiles_group(df=static_leagues, column=col, \
            quantile_range_lower=quantile_low, quantile_range_upper=quantile_up)

# Fill absolute features using already filled relative features (opposite of the relative features creation) - (Rel. value x Games played)
for key, value in features_names_links.items():
    static_leagues[key] = static_leagues[key].fillna(round(static_leagues[value] * (static_leagues['round_name'] - 1)))

# %% [markdown]
# Drop unwanted tables' features & specify data types

# %%
# Drop features by filtering columns' names
for reg in ['^Team_', '^Played_', '^season_id_', '^round_name_', '^Type_']:
    static_leagues.drop(static_leagues.filter(regex=reg).columns, axis = 1, inplace=True)
# Change features' dtype to Int64 by filtering
for feat_int in ['^Won_', '^Drawn_', '^Lost_', '^GF_', '^GA_', '^GD_', '^Points_', '^rank_']:
    static_leagues[static_leagues.filter(regex=feat_int).columns] = static_leagues.filter(regex=feat_int).astype('Int64')

# %%
# NAs test
columns_with_NA = 0
for i in static_leagues.loc[:, 'ROUND':].columns:
    if static_leagues.loc[:, i].isna().sum() != 0:
        print('NAs in', i, 'column: ', static_leagues.loc[:, i].isna().sum())
        columns_with_NA += 1
print("N. of table's features with NAs: ", columns_with_NA, "\nN. of total table's features: ", \
    static_leagues.loc[:, 'ROUND':].shape[1])
# Out:
# N. of table's features with NAs:  0
# N. of total table's features:  181

# %%
stand_cols = static_leagues.loc[:,:'winner_team_id'].columns.tolist() + ['time_starting_at_date', 'season_name'] + static_leagues.loc[:,'result':].columns.tolist()
standings_df = static_leagues.loc[:, stand_cols]
standings_df.head(3)
# Out:
#         league_id  season_id  stage_id  venue_id  referee_id  home_id  \
# id
# 251728        301        765      1392        37       15478      430
# 251738        301        765      1392      4451       11668     6789
# 2188            8         13        11       199       15241       22
#
#         away_id  winner_team_id time_starting_at_date season_name  result  \
# id
# 251728      591             591            2016-08-12   2016/2017       2
# 251738     2919               0            2016-08-12   2016/2017       0
# 2188         42              22            2016-08-13   2016/2017       1
#
#         goal_diff  ROUND  Won_FT_TO_H  Drawn_FT_TO_H  Lost_FT_TO_H  \
# id
# 251728         -1      0           12              8            16
# 251738          0      0           16             14             7
# 2188            1      0            0              0             0
#
#         GF_FT_TO_H  GA_FT_TO_H  GD_FT_TO_H  Points_FT_TO_H  rank_FT_TO_H  \
# id
# 251728          33          41          -8              44            14
# 251738          55          50           5              62             3
# 2188             0           0           0               0            17
#
#         W%_FT_TO_H  D%_FT_TO_H  L%_FT_TO_H  GFxGame_FT_TO_H  GAxGame_FT_TO_H  \
# id
# 251728    0.333333    0.222222    0.444444         0.916667         1.138889
# 251738    0.432432    0.378378    0.189189         1.486486         1.351351
# 2188      0.107143    0.142857    0.619048         0.920000         1.833333
#
#         GDxGame_FT_TO_H  PointsxGame_FT_TO_H  Won_1H_TO_H  Drawn_1H_TO_H  \
# id
# 251728        -0.222222             1.222222            7             20
# 251738         0.135135             1.675676           13             13
# 2188          -1.364179             0.857143            0              0
#
#         Lost_1H_TO_H  GF_1H_TO_H  GA_1H_TO_H  GD_1H_TO_H  Points_1H_TO_H  \
# id
# 251728             9          14          14           0              41
# 251738            11          22          22           0              52
# 2188               0           0           0           0               0
#
#         rank_1H_TO_H  W%_1H_TO_H  D%_1H_TO_H  L%_1H_TO_H  GFxGame_1H_TO_H  \
# id
# 251728            14    0.194444    0.555556    0.250000         0.388889
# 251738             8    0.351351    0.351351    0.297297         0.594595
# 2188              20    0.090909    0.200000    0.571429         0.166667
#
#         GAxGame_1H_TO_H  GDxGame_1H_TO_H  PointsxGame_1H_TO_H  Won_2H_TO_H  \
# id
# 251728         0.388889         0.000000             1.138889           10
# 251738         0.594595         0.000000             1.405405           13
# 2188           1.250000        -0.478261             0.666667            0
#
#         Drawn_2H_TO_H  Lost_2H_TO_H  GF_2H_TO_H  GA_2H_TO_H  GD_2H_TO_H  \
# id
# 251728             12            14          19          27          -8
# 251738             13            11          33          28           5
# 2188                0             0           0           0           0
#
#         Points_2H_TO_H  rank_2H_TO_H  W%_2H_TO_H  D%_2H_TO_H  L%_2H_TO_H  \
# id
# 251728              42            15    0.277778    0.333333    0.388889
# 251738              52             7    0.351351    0.351351    0.297297
# 2188                 0            19    0.000000    0.210526    0.468750
#
#         GFxGame_2H_TO_H  GAxGame_2H_TO_H  GDxGame_2H_TO_H  \
# id
# 251728         0.527778         0.750000        -0.222222
# 251738         0.891892         0.756757         0.135135
# 2188           0.400000         1.074074        -1.500000
#
#         PointsxGame_2H_TO_H  Won_FT_TO_A  Drawn_FT_TO_A  Lost_FT_TO_A  \
# id
# 251728             1.166667           27              5             2
# 251738             1.405405           11             10            15
# 2188               0.615385           23             11             3
#
#         GF_FT_TO_A  GA_FT_TO_A  GD_FT_TO_A  Points_FT_TO_A  rank_FT_TO_A  \
# id
# 251728          89          18          71              86             1
# 251738          45          53          -8              43            15
# 2188            67          35          32              80             1
#
#         W%_FT_TO_A  D%_FT_TO_A  L%_FT_TO_A  GFxGame_FT_TO_A  GAxGame_FT_TO_A  \
# id
# 251728    0.794118    0.147059    0.058824         2.617647         0.529412
# 251738    0.305556    0.277778    0.416667         1.250000         1.472222
# 2188      0.621622    0.297297    0.081081         1.810811         0.945946
#
#         GDxGame_FT_TO_A  PointsxGame_FT_TO_A  Won_1H_TO_A  Drawn_1H_TO_A  \
# id
# 251728         2.088235             2.529412           17             15
# 251738        -0.222222             1.194444            8             21
# 2188           0.864865             2.162162           17             14
#
#         Lost_1H_TO_A  GF_1H_TO_A  GA_1H_TO_A  GD_1H_TO_A  Points_1H_TO_A  \
# id
# 251728             2          35          10          25              66
# 251738             7          19          19           0              45
# 2188               6          28          13          15              65
#
#         rank_1H_TO_A  W%_1H_TO_A  D%_1H_TO_A  L%_1H_TO_A  GFxGame_1H_TO_A  \
# id
# 251728             1    0.500000    0.441176    0.058824         1.029412
# 251738             9    0.222222    0.583333    0.194444         0.527778
# 2188               1    0.459459    0.378378    0.162162         0.756757
#
#         GAxGame_1H_TO_A  GDxGame_1H_TO_A  PointsxGame_1H_TO_A  Won_2H_TO_A  \
# id
# 251728         0.294118         0.735294             1.941176           24
# 251738         0.527778         0.000000             1.250000           11
# 2188           0.351351         0.405405             1.756757           18
#
#         Drawn_2H_TO_A  Lost_2H_TO_A  GF_2H_TO_A  GA_2H_TO_A  GD_2H_TO_A  \
# id
# 251728              7             3          54           8          46
# 251738              9            16          26          34          -8
# 2188               11             8          39          22          17
#
#         Points_2H_TO_A  rank_2H_TO_A  W%_2H_TO_A  D%_2H_TO_A  L%_2H_TO_A  \
# id
# 251728              79             1    0.705882    0.205882    0.088235
# 251738              42            14    0.305556    0.250000    0.444444
# 2188                65             2    0.486486    0.297297    0.216216
#
#         GFxGame_2H_TO_A  GAxGame_2H_TO_A  GDxGame_2H_TO_A  \
# id
# 251728         1.588235         0.235294         1.352941
# 251738         0.722222         0.944444        -0.222222
# 2188           1.054054         0.594595         0.459459
#
#         PointsxGame_2H_TO_A  Won_FT_OH_H  Drawn_FT_OH_H  Lost_FT_OH_H  \
# id
# 251728             2.323529           10              2             6
# 251738             1.166667            9              6             3
# 2188               1.756757            0              0             0
#
#         GF_FT_OH_H  GA_FT_OH_H  GD_FT_OH_H  Points_FT_OH_H  rank_FT_OH_H  \
# id
# 251728          22          14           8              32             7
# 251738          28          19           9              33             7
# 2188             0           0           0               0            19
#
#         W%_FT_OH_H  D%_FT_OH_H  L%_FT_OH_H  GFxGame_FT_OH_H  GAxGame_FT_OH_H  \
# id
# 251728    0.555556    0.111111    0.333333         1.222222         0.777778
# 251738    0.500000    0.333333    0.166667         1.555556         1.055556
# 2188      0.214286    0.076923    0.714286         0.250000         1.666667
#
#         GDxGame_FT_OH_H  PointsxGame_FT_OH_H  Won_1H_OH_H  Drawn_1H_OH_H  \
# id
# 251728         0.444444             1.777778            5             10
# 251738         0.500000             1.833333            8              6
# 2188          -0.642857             0.857143            0              0
#
#         Lost_1H_OH_H  GF_1H_OH_H  GA_1H_OH_H  GD_1H_OH_H  Points_1H_OH_H  \
# id
# 251728             3          10           5           5              25
# 251738             4          13           7           6              30
# 2188               0           0           0           0               0
#
#         rank_1H_OH_H  W%_1H_OH_H  D%_1H_OH_H  L%_1H_OH_H  GFxGame_1H_OH_H  \
# id
# 251728             9    0.277778    0.555556    0.166667         0.555556
# 251738             7    0.444444    0.333333    0.222222         0.722222
# 2188              20    0.133333    0.142857    0.428571         0.000000
#
#         GAxGame_1H_OH_H  GDxGame_1H_OH_H  PointsxGame_1H_OH_H  Won_2H_OH_H  \
# id
# 251728         0.277778         0.277778             1.388889            8
# 251738         0.388889         0.333333             1.666667            7
# 2188           4.000000        -0.666667             0.928571            0
#
#         Drawn_2H_OH_H  Lost_2H_OH_H  GF_2H_OH_H  GA_2H_OH_H  GD_2H_OH_H  \
# id
# 251728              5             5          12           9           3
# 251738              7             4          15          12           3
# 2188                0             0           0           0           0
#
#         Points_2H_OH_H  rank_2H_OH_H  W%_2H_OH_H  D%_2H_OH_H  L%_2H_OH_H  \
# id
# 251728              29             5    0.444444    0.277778    0.277778
# 251738              28            10    0.388889    0.388889    0.222222
# 2188                 0            18    0.166667    0.062500    0.666667
#
#         GFxGame_2H_OH_H  GAxGame_2H_OH_H  GDxGame_2H_OH_H  \
# id
# 251728         0.666667         0.500000         0.166667
# 251738         0.833333         0.666667         0.166667
# 2188           0.470588         1.062500        -0.666667
#
#         PointsxGame_2H_OH_H  Won_FT_OA_A  Drawn_FT_OA_A  Lost_FT_OA_A  \
# id
# 251728             1.611111           14              2             1
# 251738             1.555556            5              3            10
# 2188               0.500000           11              5             2
#
#         GF_FT_OA_A  GA_FT_OA_A  GD_FT_OA_A  Points_FT_OA_A  rank_FT_OA_A  \
# id
# 251728          38           6          32              44             1
# 251738          16          28         -12              18            14
# 2188            32          17          15              38             1
#
#         W%_FT_OA_A  D%_FT_OA_A  L%_FT_OA_A  GFxGame_FT_OA_A  GAxGame_FT_OA_A  \
# id
# 251728    0.823529    0.117647    0.058824         2.235294         0.352941
# 251738    0.277778    0.166667    0.555556         0.888889         1.555556
# 2188      0.611111    0.277778    0.111111         1.777778         0.944444
#
#         GDxGame_FT_OA_A  PointsxGame_FT_OA_A  Won_1H_OA_A  Drawn_1H_OA_A  \
# id
# 251728         1.882353             2.588235            4             11
# 251738        -0.666667             1.000000            4             10
# 2188           0.833333             2.111111            8              6
#
#         Lost_1H_OA_A  GF_1H_OA_A  GA_1H_OA_A  GD_1H_OA_A  Points_1H_OA_A  \
# id
# 251728             2          10           4           6              23
# 251738             4           6           9          -3              22
# 2188               4          12           8           4              30
#
#         rank_1H_OA_A  W%_1H_OA_A  D%_1H_OA_A  L%_1H_OA_A  GFxGame_1H_OA_A  \
# id
# 251728             6    0.235294    0.647059    0.117647         0.588235
# 251738            12    0.222222    0.555556    0.222222         0.333333
# 2188               1    0.444444    0.333333    0.222222         0.666667
#
#         GAxGame_1H_OA_A  GDxGame_1H_OA_A  PointsxGame_1H_OA_A  Won_2H_OA_A  \
# id
# 251728         0.235294         0.352941             1.352941           14
# 251738         0.500000        -0.166667             1.222222            4
# 2188           0.444444         0.222222             1.666667           11
#
#         Drawn_2H_OA_A  Lost_2H_OA_A  GF_2H_OA_A  GA_2H_OA_A  GD_2H_OA_A  \
# id
# 251728              2             1          28           2          26
# 251738              5             9          10          19          -9
# 2188                3             4          20           9          11
#
#         Points_2H_OA_A  rank_2H_OA_A  W%_2H_OA_A  D%_2H_OA_A  L%_2H_OA_A  \
# id
# 251728              44             1    0.823529    0.117647    0.058824
# 251738              17            15    0.222222    0.277778    0.500000
# 2188                36             1    0.611111    0.166667    0.222222
#
#         GFxGame_2H_OA_A  GAxGame_2H_OA_A  GDxGame_2H_OA_A  PointsxGame_2H_OA_A
# id
# 251728         1.647059         0.117647         1.529412             2.588235
# 251738         0.555556         1.055556        -0.500000             0.944444
# 2188           1.111111         0.500000         0.611111             2.000000

# %%
standings_df.to_csv('../../Data/Modeling_Before_Preparation/Standings_v01.csv')

# %% [markdown]
# ## *Weather Data*

# %% [markdown]
# Distance Function

# %%
def create_travel_distance(df):
    d = {}
    s = set()
    for i, id in enumerate(df.loc[:, 'home_id']):
        if id not in s:
            s.add(id)
            d[id] = df['venue_coordinates'].iloc[i]

    df['coord_away'] = df['away_id'].map(d)
    df['travel_dist(km)'] = df.apply(lambda row: \
        distance.distance(eval(row['venue_coordinates']), eval(row['coord_away'])).km, axis=1)
    df['travel_dist(km)'] = pd.to_numeric(df['travel_dist(km)'].round(0).astype(int), errors='coerce', downcast='integer')
    return df

# %% [markdown]
# Weather Data Preparation

# %%
# Import Data
weather_data = pd.read_csv('../../Data/From_Collection/Weather_output/weather_output.csv').set_index('id')
# Create new columns from Time variable
weather_data['time'] = weather_data['time'].apply(lambda x: datetime.fromisoformat(x))
weather_data['year'] = pd.to_datetime(weather_data['time']).dt.year
weather_data['month'] = pd.to_datetime(weather_data['time']).dt.month
weather_data['hour'] = pd.to_datetime(weather_data['time']).dt.time

# %% [markdown]
# Merge Static and Weather Data (using static columns to fill weather NAs)

# %%
# Merge static_leagues with weather data by Index
static_leagues = pd.merge(static_leagues, weather_data, how='left', left_index=True, right_index=True)
# Convert windspeed column from kph to m/s
static_leagues['windspeed'] = round((static_leagues['windspeed'] / 3.6), 2)
# Using static columns to fill weather columns
fill_weather_cols = {'windspeed': 'weather_report_windspeed(m/s)', 'winddir': 'weather_report_wind_degree', 'cloudcover': 'weather_report_clouds(%)', 'humidity': 'weather_report_humidity(%)', 'temp': 'weather_report_temp_celsius', 'pressure': 'weather_report_pressure'}
for key, value in fill_weather_cols.items():
    static_leagues[key].fillna(static_leagues[value], inplace=True)

# %% [markdown]
# Fill Weather NAs & Convert Dtypes

# %%
# Fill weather NAs from columns' list
for col in ['temp', 'precip', 'cloudcover', 'humidity', 'pressure', 'winddir', 'windspeed', 'visibility']:
    static_leagues.loc[:, col] = static_leagues.groupby(['venue_city', 'month'])[col].apply(lambda x: x.fillna(x.mean()))
    static_leagues.loc[:, col] = static_leagues.groupby(['home_country_id', 'month'])[col].apply(lambda x: x.fillna(x.mean()))
# Change weather columns dtypes and round float columns
for col in ['winddir', 'cloudcover', 'humidity', 'pressure', 'visibility']:
    static_leagues[col] = static_leagues[col].astype(int)
static_leagues['temp'] = static_leagues['temp'].apply(lambda x: round(x, 1))
static_leagues['windspeed'] = static_leagues['windspeed'].apply(lambda x: round(x, 2))

# %% [markdown]
# Create night_game Column (using sunset feature)

# %%
# Convert sunset column from string to datetime & convert all times to Rome time-zone
repl_dict = {re.compile('\+\d{2}:\d{2}$'): '', re.compile('Z$'): ''}
static_leagues.loc[:, 'sunset'] = static_leagues.loc[:, 'sunset'].replace(repl_dict, regex=True)
static_leagues['sunset'] = pd.to_datetime(static_leagues['sunset'], format='%Y-%m-%dT%H:%M:%S', errors='coerce')
static_leagues['sunset_rome_TZ'] = np.where(static_leagues['league_name'] == 'Premier League', \
    static_leagues['sunset'] + timedelta(hours=1), static_leagues['sunset'])
# Fill NAs for sunset column by city/country and month
static_leagues['sunset_rome_TZ'] = static_leagues.groupby(['venue_city', 'month'])['sunset_rome_TZ'].apply(lambda x: \
    x.fillna(method='ffill').fillna(method='bfill'))
static_leagues['sunset_rome_TZ'] = static_leagues.groupby(['home_country_id', 'month'])['sunset_rome_TZ'].apply(lambda x: \
    x.fillna(method='ffill').fillna(method='bfill'))
# Create new variable night_game (games played after sunset for at least one half) comparing match time and sunset time
static_leagues['night_game'] = np.where(static_leagues['hour'] >= ((static_leagues['sunset_rome_TZ'] - timedelta(minutes=45)).dt.time), 1, 0)
# Out:
# /Library/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /Library/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   del sys.path[0]

# %% [markdown]
# Drop Valueless Columns

# %%
# Drop not useful weather columns 
weather_cols_drop = ['precip', 'sunset', 'windgust', 'year', 'month', 'hour', 'sunset_rome_TZ', 'weather_report_code', 'weather_report_type', 'weather_report_windspeed(m/s)', 'weather_report_wind_degree', 'weather_report_clouds(%)', 'weather_report_humidity(%)', 'weather_report_pressure', 'weather_lat_lon', 'weather_report_temp_celsius']
static_leagues = static_leagues.drop(columns=weather_cols_drop)
static_leagues.head()
# Out:
#         league_id  season_id  stage_id  venue_id  referee_id  home_id  \
# id
# 251728        301        765      1392        37       15478      430
# 251738        301        765      1392      4451       11668     6789
# 2188            8         13        11       199       15241       22
# 2208            8         13        11       201       15293       51
# 2225            8         13        11       203       15242        7
#
#         away_id  winner_team_id  commentaries  attendance  \
# id
# 251728      591             591             1       13122
# 251738     2919               0             1        8019
# 2188         42              22             1       20137
# 2208         10              10             1       24490
# 2225         26               0             1       32110
#
#        formations_home_formation formations_away_formation  scores_home_score  \
# id
# 251728                   4-3-2-1                   4-2-3-1                  0
# 251738                     4-4-2                   4-2-2-2                  2
# 2188                       4-3-3                     4-4-2                  2
# 2208                     4-2-3-1                     4-4-2                  0
# 2225                     4-2-3-1                   4-2-3-1                  1
#
#         scores_away_score scores_ht_score scores_ft_score scores_et_score  \
# id
# 251728                  1             0-0             0-1             NaN
# 251738                  2             0-2             2-2             NaN
# 2188                    1             1-0             2-1             NaN
# 2208                    1             0-0             0-1             NaN
# 2225                    1             1-0             1-1             NaN
#
#        scores_ps_score time_starting_at_date_time time_starting_at_date  \
# id
# 251728             NaN        2016-08-12 20:00:00            2016-08-12
# 251738             NaN        2016-08-12 20:30:00            2016-08-12
# 2188               NaN        2016-08-13 13:30:00            2016-08-13
# 2208               NaN        2016-08-13 16:00:00            2016-08-13
# 2225               NaN        2016-08-13 16:00:00            2016-08-13
#
#        time_starting_at_timezone  time_minute  standings_home_position  \
# id
# 251728               Europe/Rome           90                     <NA>
# 251738               Europe/Rome           90                     <NA>
# 2188                 Europe/Rome           90                     <NA>
# 2208                 Europe/Rome           90                     <NA>
# 2225                 Europe/Rome           90                     <NA>
#
#         standings_away_position       home_name home_twitter  home_country_id  \
# id
# 251728                     <NA>          Bastia    @SCBastia               17
# 251738                     <NA>          Monaco   @AS_Monaco            75285
# 2188                       <NA>       Hull City    @HullCity              462
# 2208                       <NA>  Crystal Palace        @CPFC              462
# 2225                       <NA>   Middlesbrough        @Boro              462
#
#         home_founded  home_venue_id             away_name away_twitter  \
# id
# 251728          1905             37   Paris Saint Germain  @PSG_inside
# 251738          1919           4451              Guingamp  @EAGuingamp
# 2188            1904            199        Leicester City        @LCFC
# 2208            1905            201  West Bromwich Albion         @WBA
# 2225            1876            203            Stoke City   @stokecity
#
#         away_country_id  away_founded  away_venue_id league_type  \
# id
# 251728               17          1970            131    domestic
# 251738               17          1912           1715    domestic
# 2188                462          1884            117    domestic
# 2208                462          1878            119    domestic
# 2225                462          1868            207    domestic
#
#         league_country_id     league_name  league_is_cup season_name  \
# id
# 251728                 17         Ligue 1              0   2016/2017
# 251738                 17         Ligue 1              0   2016/2017
# 2188                  462  Premier League              0   2016/2017
# 2208                  462  Premier League              0   2016/2017
# 2225                  462  Premier League              0   2016/2017
#
#         round_name round_start  round_end           venue_name  \
# id
# 251728           1  2016-08-12 2016-08-14  Stade Armand-Césari
# 251738           1  2016-08-12 2016-08-14      Stade Louis II.
# 2188             1  2016-08-13 2016-08-15         KCOM Stadium
# 2208             1  2016-08-13 2016-08-15        Selhurst Park
# 2225             1  2016-08-13 2016-08-15    Riverside Stadium
#
#         venue_surface_isgrass     venue_city  venue_capacity  \
# id
# 251728                      1        Furiani           16078
# 251738                      1         Monaco           18523
# 2188                        1           Hull           25400
# 2208                        1         London           25073
# 2225                        1  Middlesbrough           34988
#
#             venue_coordinates    referee_fullname  homecoach_coach_id  \
# id
# 251728   (42.651400,9.442619)     Frank Schneider              896573
# 251738   (43.727606,7.415614)  Jérôme Miguelgorry              896525
# 2188    (53.746111,-0.367778)           Mike Dean              896472
# 2208    (51.398333,-0.085556)        Craig Pawson              896470
# 2225    (54.578333,-1.216944)        Kevin Friend              896473
#
#         homecoach_country_id                      homecoach_fullname  \
# id
# 251728                    17                      François Ciccolini
# 251738                    20  José Leonardo Nunes Alves Sousa Jardim
# 2188                     462                             Mike Phelan
# 2208                     462                             Alan Pardew
# 2225                      32                 Aitor Karanka de la Hoz
#
#        homecoach_nationality homecoach_birthdate homecoach_birthcountry  \
# id
# 251728                France          1962-06-03                 France
# 251738              Portugal          1974-08-01              Venezuela
# 2188                 England          1962-09-24                England
# 2208                 England          1961-07-18                England
# 2225                   Spain          1973-09-18                  Spain
#
#         awaycoach_coach_id  awaycoach_country_id    awaycoach_fullname  \
# id
# 251728              455907                    32  Unai Emery Etxegoien
# 251738              459054                    17     Antoine Kombouare
# 2188                893654                   251       Claudio Ranieri
# 2208                455360                   515            Tony Pulis
# 2225                455458                   515           Mark Hughes
#
#        awaycoach_nationality awaycoach_birthdate awaycoach_birthcountry  \
# id
# 251728                 Spain          1971-11-03                  Spain
# 251738                France          1963-11-16          New Caledonia
# 2188                   Italy          1951-10-20                  Italy
# 2208                   Wales          1958-01-16                  Wales
# 2225                   Wales          1963-11-01                  Wales
#
#        colors_home_color colors_away_color  home_shots_total  \
# id
# 251728           #202A44           #F0F0F0                10
# 251738           #C40010           #C40010                18
# 2188             #FC7E00           #B0E8E6                14
# 2208             #0046A8           #025C17                14
# 2225             #C40010           #339063                12
#
#         home_shots_ongoal  home_shots_offgoal  home_shots_blocked  \
# id
# 251728                  0                   9                   1
# 251738                  4                   8                   6
# 2188                    5                   7                   2
# 2208                    4                   7                   3
# 2225                    2                   6                   4
#
#         home_shots_insidebox  home_shots_outsidebox  home_fouls  home_corners  \
# id
# 251728                     4                      6          15             2
# 251738                    12                      6          14             8
# 2188                       7                      7           8             5
# 2208                       7                      7          12             3
# 2225                       8                      4          18             9
#
#         home_offsides  home_possessiontime  home_yellowcards  home_redcards  \
# id
# 251728              0                   26                 3              0
# 251738              1                   70                 3              0
# 2188                1                   49                 2              0
# 2208                0                   62                 2              0
# 2225                1                   45                 3              0
#
#         home_yellowredcards  home_saves  home_tackles  away_shots_total  \
# id
# 251728                    0           5            24                 9
# 251738                    0           3            13                 9
# 2188                      0           4            20                18
# 2208                      0           2            28                13
# 2225                      0           1            17                12
#
#         away_shots_ongoal  away_shots_offgoal  away_shots_blocked  \
# id
# 251728                  6                   3                   0
# 251738                  5                   3                   1
# 2188                    5                   9                   4
# 2208                    3                   8                   2
# 2225                    1                   9                   2
#
#         away_shots_insidebox  away_shots_outsidebox  away_fouls  away_corners  \
# id
# 251728                     6                      3          16             6
# 251738                     4                      5          15             2
# 2188                       9                      9          17             3
# 2208                       8                      5          15             6
# 2225                       7                      5          14             6
#
#         away_offsides  away_possessiontime  away_yellowcards  away_redcards  \
# id
# 251728              3                   74                 3              0
# 251738              1                   30                 4              0
# 2188                0                   51                 2              0
# 2208                2                   38                 2              0
# 2225                2                   55                 5              0
#
#         away_yellowredcards  away_saves  away_tackles  home_passes_total  \
# id
# 251728                    0           0            14                215
# 251738                    0           2            22                513
# 2188                      0           3            14                449
# 2208                      0           4            18                414
# 2225                      0           1            16                349
#
#         home_passes_accurate  home_passes_percentage  away_passes_total  \
# id
# 251728                   134                    62.0                600
# 251738                   446                    87.0                223
# 2188                     343                    76.0                453
# 2208                     298                    72.0                245
# 2225                     262                    75.0                420
#
#         away_passes_accurate  away_passes_percentage  home_attacks_attacks  \
# id
# 251728                   529                    88.0                   101
# 251738                   124                    56.0                   115
# 2188                     352                    78.0                   110
# 2208                     143                    58.0                   110
# 2225                     330                    79.0                   106
#
#         home_attacks_dangerous_attacks  away_attacks_attacks  \
# id
# 251728                              43                    96
# 251738                              53                    96
# 2188                                55                   113
# 2208                                53                   106
# 2225                                48                   103
#
#         away_attacks_dangerous_attacks  result  goal_diff  ROUND  Won_FT_TO_H  \
# id
# 251728                              52       2         -1      0           12
# 251738                              49       0          0      0           16
# 2188                                49       1          1      0            0
# 2208                                45       2         -1      0           10
# 2225                                40       0          0      0            0
#
#         Drawn_FT_TO_H  Lost_FT_TO_H  GF_FT_TO_H  GA_FT_TO_H  GD_FT_TO_H  \
# id
# 251728              8            16          33          41          -8
# 251738             14             7          55          50           5
# 2188                0             0           0           0           0
# 2208                9            17          36          46         -10
# 2225                0             0           0           0           0
#
#         Points_FT_TO_H  rank_FT_TO_H  W%_FT_TO_H  D%_FT_TO_H  L%_FT_TO_H  \
# id
# 251728              44            14    0.333333    0.222222    0.444444
# 251738              62             3    0.432432    0.378378    0.189189
# 2188                 0            17    0.107143    0.142857    0.619048
# 2208                39            16    0.277778    0.250000    0.472222
# 2225                 0            16    0.125000    0.142857    0.704736
#
#         GFxGame_FT_TO_H  GAxGame_FT_TO_H  GDxGame_FT_TO_H  \
# id
# 251728         0.916667         1.138889        -0.222222
# 251738         1.486486         1.351351         0.135135
# 2188           0.920000         1.833333        -1.364179
# 2208           1.000000         1.277778        -0.277778
# 2225           0.500000         2.071429        -1.285714
#
#         PointsxGame_FT_TO_H  Won_1H_TO_H  Drawn_1H_TO_H  Lost_1H_TO_H  \
# id
# 251728             1.222222            7             20             9
# 251738             1.675676           13             13            11
# 2188               0.857143            0              0             0
# 2208               1.083333            5             22             9
# 2225               0.416667            0              0             0
#
#         GF_1H_TO_H  GA_1H_TO_H  GD_1H_TO_H  Points_1H_TO_H  rank_1H_TO_H  \
# id
# 251728          14          14           0              41            14
# 251738          22          22           0              52             8
# 2188             0           0           0               0            20
# 2208            13          19          -6              37            16
# 2225             0           0           0               0            18
#
#         W%_1H_TO_H  D%_1H_TO_H  L%_1H_TO_H  GFxGame_1H_TO_H  GAxGame_1H_TO_H  \
# id
# 251728    0.194444    0.555556    0.250000         0.388889         0.388889
# 251738    0.351351    0.351351    0.297297         0.594595         0.594595
# 2188      0.090909    0.200000    0.571429         0.166667         1.250000
# 2208      0.138889    0.611111    0.250000         0.361111         0.527778
# 2225      0.117647    0.285714    0.600000         0.214286         0.812500
#
#         GDxGame_1H_TO_H  PointsxGame_1H_TO_H  Won_2H_TO_H  Drawn_2H_TO_H  \
# id
# 251728         0.000000             1.138889           10             12
# 251738         0.000000             1.405405           13             13
# 2188          -0.478261             0.666667            0              0
# 2208          -0.166667             1.027778           13              8
# 2225          -1.000000             0.500000            0              0
#
#         Lost_2H_TO_H  GF_2H_TO_H  GA_2H_TO_H  GD_2H_TO_H  Points_2H_TO_H  \
# id
# 251728            14          19          27          -8              42
# 251738            11          33          28           5              52
# 2188               0           0           0           0               0
# 2208              15          23          27          -4              47
# 2225               0           0           0           0               0
#
#         rank_2H_TO_H  W%_2H_TO_H  D%_2H_TO_H  L%_2H_TO_H  GFxGame_2H_TO_H  \
# id
# 251728            15    0.277778    0.333333    0.388889         0.527778
# 251738             7    0.351351    0.351351    0.297297         0.891892
# 2188              19    0.000000    0.210526    0.468750         0.400000
# 2208               9    0.361111    0.222222    0.416667         0.638889
# 2225              17    0.157895    0.166667    0.666667         0.000000
#
#         GAxGame_2H_TO_H  GDxGame_2H_TO_H  PointsxGame_2H_TO_H  Won_FT_TO_A  \
# id
# 251728         0.750000        -0.222222             1.166667           27
# 251738         0.756757         0.135135             1.405405           11
# 2188           1.074074        -1.500000             0.615385           23
# 2208           0.750000        -0.111111             1.305556           10
# 2225           1.117647        -0.517779             0.400000           13
#
#         Drawn_FT_TO_A  Lost_FT_TO_A  GF_FT_TO_A  GA_FT_TO_A  GD_FT_TO_A  \
# id
# 251728              5             2          89          18          71
# 251738             10            15          45          53          -8
# 2188               11             3          67          35          32
# 2208               11            15          32          46         -14
# 2225                9            14          38          52         -14
#
#         Points_FT_TO_A  rank_FT_TO_A  W%_FT_TO_A  D%_FT_TO_A  L%_FT_TO_A  \
# id
# 251728              86             1    0.794118    0.147059    0.058824
# 251738              43            15    0.305556    0.277778    0.416667
# 2188                80             1    0.621622    0.297297    0.081081
# 2208                41            14    0.277778    0.305556    0.416667
# 2225                48            10    0.361111    0.250000    0.388889
#
#         GFxGame_FT_TO_A  GAxGame_FT_TO_A  GDxGame_FT_TO_A  \
# id
# 251728         2.617647         0.529412         2.088235
# 251738         1.250000         1.472222        -0.222222
# 2188           1.810811         0.945946         0.864865
# 2208           0.888889         1.277778        -0.388889
# 2225           1.055556         1.444444        -0.388889
#
#         PointsxGame_FT_TO_A  Won_1H_TO_A  Drawn_1H_TO_A  Lost_1H_TO_A  \
# id
# 251728             2.529412           17             15             2
# 251738             1.194444            8             21             7
# 2188               2.162162           17             14             6
# 2208               1.138889            7             18            11
# 2225               1.333333           10             13            13
#
#         GF_1H_TO_A  GA_1H_TO_A  GD_1H_TO_A  Points_1H_TO_A  rank_1H_TO_A  \
# id
# 251728          35          10          25              66             1
# 251738          19          19           0              45             9
# 2188            28          13          15              65             1
# 2208            16          23          -7              39            14
# 2225            16          22          -6              43            13
#
#         W%_1H_TO_A  D%_1H_TO_A  L%_1H_TO_A  GFxGame_1H_TO_A  GAxGame_1H_TO_A  \
# id
# 251728    0.500000    0.441176    0.058824         1.029412         0.294118
# 251738    0.222222    0.583333    0.194444         0.527778         0.527778
# 2188      0.459459    0.378378    0.162162         0.756757         0.351351
# 2208      0.194444    0.500000    0.305556         0.444444         0.638889
# 2225      0.277778    0.361111    0.361111         0.444444         0.611111
#
#         GDxGame_1H_TO_A  PointsxGame_1H_TO_A  Won_2H_TO_A  Drawn_2H_TO_A  \
# id
# 251728         0.735294             1.941176           24              7
# 251738         0.000000             1.250000           11              9
# 2188           0.405405             1.756757           18             11
# 2208          -0.194444             1.083333            9             16
# 2225          -0.166667             1.194444            9             15
#
#         Lost_2H_TO_A  GF_2H_TO_A  GA_2H_TO_A  GD_2H_TO_A  Points_2H_TO_A  \
# id
# 251728             3          54           8          46              79
# 251738            16          26          34          -8              42
# 2188               8          39          22          17              65
# 2208              11          16          23          -7              43
# 2225              12          22          30          -8              42
#
#         rank_2H_TO_A  W%_2H_TO_A  D%_2H_TO_A  L%_2H_TO_A  GFxGame_2H_TO_A  \
# id
# 251728             1    0.705882    0.205882    0.088235         1.588235
# 251738            14    0.305556    0.250000    0.444444         0.722222
# 2188               2    0.486486    0.297297    0.216216         1.054054
# 2208              14    0.250000    0.444444    0.305556         0.444444
# 2225              15    0.250000    0.416667    0.333333         0.611111
#
#         GAxGame_2H_TO_A  GDxGame_2H_TO_A  PointsxGame_2H_TO_A  Won_FT_OH_H  \
# id
# 251728         0.235294         1.352941             2.323529           10
# 251738         0.944444        -0.222222             1.166667            9
# 2188           0.594595         0.459459             1.756757            0
# 2208           0.638889        -0.194444             1.194444            5
# 2225           0.833333        -0.222222             1.166667            0
#
#         Drawn_FT_OH_H  Lost_FT_OH_H  GF_FT_OH_H  GA_FT_OH_H  GD_FT_OH_H  \
# id
# 251728              2             6          22          14           8
# 251738              6             3          28          19           9
# 2188                0             0           0           0           0
# 2208                3            10          17          22          -5
# 2225                0             0           0           0           0
#
#         Points_FT_OH_H  rank_FT_OH_H  W%_FT_OH_H  D%_FT_OH_H  L%_FT_OH_H  \
# id
# 251728              32             7    0.555556    0.111111    0.333333
# 251738              33             7    0.500000    0.333333    0.166667
# 2188                 0            19    0.214286    0.076923    0.714286
# 2208                18            19    0.277778    0.166667    0.555556
# 2225                 0            20    0.214286    0.000000    0.857143
#
#         GFxGame_FT_OH_H  GAxGame_FT_OH_H  GDxGame_FT_OH_H  \
# id
# 251728         1.222222         0.777778         0.444444
# 251738         1.555556         1.055556         0.500000
# 2188           0.250000         1.666667        -0.642857
# 2208           0.944444         1.222222        -0.277778
# 2225           0.900000         1.818182        -1.666667
#
#         PointsxGame_FT_OH_H  Won_1H_OH_H  Drawn_1H_OH_H  Lost_1H_OH_H  \
# id
# 251728             1.777778            5             10             3
# 251738             1.833333            8              6             4
# 2188               0.857143            0              0             0
# 2208               1.000000            3             13             2
# 2225               0.800000            0              0             0
#
#         GF_1H_OH_H  GA_1H_OH_H  GD_1H_OH_H  Points_1H_OH_H  rank_1H_OH_H  \
# id
# 251728          10           5           5              25             9
# 251738          13           7           6              30             7
# 2188             0           0           0               0            20
# 2208             9           7           2              22            13
# 2225             0           0           0               0            17
#
#         W%_1H_OH_H  D%_1H_OH_H  L%_1H_OH_H  GFxGame_1H_OH_H  GAxGame_1H_OH_H  \
# id
# 251728    0.277778    0.555556    0.166667         0.555556         0.277778
# 251738    0.444444    0.333333    0.222222         0.722222         0.388889
# 2188      0.133333    0.142857    0.428571         0.000000         4.000000
# 2208      0.166667    0.722222    0.111111         0.500000         0.388889
# 2225      0.066667    0.125000    0.600000         0.300000         1.000000
#
#         GDxGame_1H_OH_H  PointsxGame_1H_OH_H  Won_2H_OH_H  Drawn_2H_OH_H  \
# id
# 251728         0.277778             1.388889            8              5
# 251738         0.333333             1.666667            7              7
# 2188          -0.666667             0.928571            0              0
# 2208           0.111111             1.222222            4              5
# 2225          -0.277778             0.500000            0              0
#
#         Lost_2H_OH_H  GF_2H_OH_H  GA_2H_OH_H  GD_2H_OH_H  Points_2H_OH_H  \
# id
# 251728             5          12           9           3              29
# 251738             4          15          12           3              28
# 2188               0           0           0           0               0
# 2208               9           8          15          -7              17
# 2225               0           0           0           0               0
#
#         rank_2H_OH_H  W%_2H_OH_H  D%_2H_OH_H  L%_2H_OH_H  GFxGame_2H_OH_H  \
# id
# 251728             5    0.444444    0.277778    0.277778         0.666667
# 251738            10    0.388889    0.388889    0.222222         0.833333
# 2188              18    0.166667    0.062500    0.666667         0.470588
# 2208              20    0.222222    0.277778    0.500000         0.444444
# 2225              16    0.117647    0.125000    0.500000         0.300000
#
#         GAxGame_2H_OH_H  GDxGame_2H_OH_H  PointsxGame_2H_OH_H  Won_FT_OA_A  \
# id
# 251728         0.500000         0.166667             1.611111           14
# 251738         0.666667         0.166667             1.555556            5
# 2188           1.062500        -0.666667             0.500000           11
# 2208           0.833333        -0.388889             0.944444            4
# 2225           1.400000        -0.444444             0.900000            6
#
#         Drawn_FT_OA_A  Lost_FT_OA_A  GF_FT_OA_A  GA_FT_OA_A  GD_FT_OA_A  \
# id
# 251728              2             1          38           6          32
# 251738              3            10          16          28         -12
# 2188                5             2          32          17          15
# 2208                7             7          13          21          -8
# 2225                5             7          18          29         -11
#
#         Points_FT_OA_A  rank_FT_OA_A  W%_FT_OA_A  D%_FT_OA_A  L%_FT_OA_A  \
# id
# 251728              44             1    0.823529    0.117647    0.058824
# 251738              18            14    0.277778    0.166667    0.555556
# 2188                38             1    0.611111    0.277778    0.111111
# 2208                19            15    0.222222    0.388889    0.388889
# 2225                23            10    0.333333    0.277778    0.388889
#
#         GFxGame_FT_OA_A  GAxGame_FT_OA_A  GDxGame_FT_OA_A  \
# id
# 251728         2.235294         0.352941         1.882353
# 251738         0.888889         1.555556        -0.666667
# 2188           1.777778         0.944444         0.833333
# 2208           0.722222         1.166667        -0.444444
# 2225           1.000000         1.611111        -0.611111
#
#         PointsxGame_FT_OA_A  Won_1H_OA_A  Drawn_1H_OA_A  Lost_1H_OA_A  \
# id
# 251728             2.588235            4             11             2
# 251738             1.000000            4             10             4
# 2188               2.111111            8              6             4
# 2208               1.055556            3              8             7
# 2225               1.277778            5              6             7
#
#         GF_1H_OA_A  GA_1H_OA_A  GD_1H_OA_A  Points_1H_OA_A  rank_1H_OA_A  \
# id
# 251728          10           4           6              23             6
# 251738           6           9          -3              22            12
# 2188            12           8           4              30             1
# 2208             7          13          -6              17            14
# 2225             8          13          -5              21            10
#
#         W%_1H_OA_A  D%_1H_OA_A  L%_1H_OA_A  GFxGame_1H_OA_A  GAxGame_1H_OA_A  \
# id
# 251728    0.235294    0.647059    0.117647         0.588235         0.235294
# 251738    0.222222    0.555556    0.222222         0.333333         0.500000
# 2188      0.444444    0.333333    0.222222         0.666667         0.444444
# 2208      0.166667    0.444444    0.388889         0.388889         0.722222
# 2225      0.277778    0.333333    0.388889         0.444444         0.722222
#
#         GDxGame_1H_OA_A  PointsxGame_1H_OA_A  Won_2H_OA_A  Drawn_2H_OA_A  \
# id
# 251728         0.352941             1.352941           14              2
# 251738        -0.166667             1.222222            4              5
# 2188           0.222222             1.666667           11              3
# 2208          -0.333333             0.944444            4             10
# 2225          -0.277778             1.166667            4              7
#
#         Lost_2H_OA_A  GF_2H_OA_A  GA_2H_OA_A  GD_2H_OA_A  Points_2H_OA_A  \
# id
# 251728             1          28           2          26              44
# 251738             9          10          19          -9              17
# 2188               4          20           9          11              36
# 2208               4           6           8          -2              22
# 2225               7          10          16          -6              19
#
#         rank_2H_OA_A  W%_2H_OA_A  D%_2H_OA_A  L%_2H_OA_A  GFxGame_2H_OA_A  \
# id
# 251728             1    0.823529    0.117647    0.058824         1.647059
# 251738            15    0.222222    0.277778    0.500000         0.555556
# 2188               1    0.611111    0.166667    0.222222         1.111111
# 2208              10    0.222222    0.555556    0.222222         0.333333
# 2225              14    0.222222    0.388889    0.388889         0.555556
#
#         GAxGame_2H_OA_A  GDxGame_2H_OA_A  PointsxGame_2H_OA_A  \
# id
# 251728         0.117647         1.529412             2.588235
# 251738         1.055556        -0.500000             0.944444
# 2188           0.500000         0.611111             2.000000
# 2208           0.444444        -0.111111             1.222222
# 2225           0.888889        -0.333333             1.055556
#
#                       time        lat       lon  temp  cloudcover  humidity  \
# id
# 251728 2016-08-12 20:00:00  42.651400  9.442619  23.9          27        48
# 251738 2016-08-12 20:30:00  43.727606  7.415614  17.9          25        73
# 2188   2016-08-13 13:30:00  53.746111 -0.367778  20.2          54        62
# 2208   2016-08-13 16:00:00  51.398333 -0.085556  22.2          38        62
# 2225   2016-08-13 16:00:00  54.578333 -1.216944  19.0          63        61
#
#         pressure  visibility  winddir  windspeed  night_game
# id
# 251728      1022          30       21       3.06           1
# 251738      1014          10      312       0.92           1
# 2188        1014          10      315       3.36           0
# 2208        1022          43      243       4.28           0
# 2225        1019          39      279       7.39           0

# %% [markdown]
# Filter for venue data

# %%
columns_venue_data = static_leagues.loc[:, :'colors_away_color'].columns.tolist() + ['result', 'goal_diff'] + \
    static_leagues.loc[:, 'time':].columns.tolist()
venue_data = static_leagues.loc[:, columns_venue_data]
venue_data = create_travel_distance(venue_data)
venue_data.head()
# Out:
#         league_id  season_id  stage_id  venue_id  referee_id  home_id  \
# id
# 251728        301        765      1392        37       15478      430
# 251738        301        765      1392      4451       11668     6789
# 2188            8         13        11       199       15241       22
# 2208            8         13        11       201       15293       51
# 2225            8         13        11       203       15242        7
#
#         away_id  winner_team_id  commentaries  attendance  \
# id
# 251728      591             591             1       13122
# 251738     2919               0             1        8019
# 2188         42              22             1       20137
# 2208         10              10             1       24490
# 2225         26               0             1       32110
#
#        formations_home_formation formations_away_formation  scores_home_score  \
# id
# 251728                   4-3-2-1                   4-2-3-1                  0
# 251738                     4-4-2                   4-2-2-2                  2
# 2188                       4-3-3                     4-4-2                  2
# 2208                     4-2-3-1                     4-4-2                  0
# 2225                     4-2-3-1                   4-2-3-1                  1
#
#         scores_away_score scores_ht_score scores_ft_score scores_et_score  \
# id
# 251728                  1             0-0             0-1             NaN
# 251738                  2             0-2             2-2             NaN
# 2188                    1             1-0             2-1             NaN
# 2208                    1             0-0             0-1             NaN
# 2225                    1             1-0             1-1             NaN
#
#        scores_ps_score time_starting_at_date_time time_starting_at_date  \
# id
# 251728             NaN        2016-08-12 20:00:00            2016-08-12
# 251738             NaN        2016-08-12 20:30:00            2016-08-12
# 2188               NaN        2016-08-13 13:30:00            2016-08-13
# 2208               NaN        2016-08-13 16:00:00            2016-08-13
# 2225               NaN        2016-08-13 16:00:00            2016-08-13
#
#        time_starting_at_timezone  time_minute  standings_home_position  \
# id
# 251728               Europe/Rome           90                     <NA>
# 251738               Europe/Rome           90                     <NA>
# 2188                 Europe/Rome           90                     <NA>
# 2208                 Europe/Rome           90                     <NA>
# 2225                 Europe/Rome           90                     <NA>
#
#         standings_away_position       home_name home_twitter  home_country_id  \
# id
# 251728                     <NA>          Bastia    @SCBastia               17
# 251738                     <NA>          Monaco   @AS_Monaco            75285
# 2188                       <NA>       Hull City    @HullCity              462
# 2208                       <NA>  Crystal Palace        @CPFC              462
# 2225                       <NA>   Middlesbrough        @Boro              462
#
#         home_founded  home_venue_id             away_name away_twitter  \
# id
# 251728          1905             37   Paris Saint Germain  @PSG_inside
# 251738          1919           4451              Guingamp  @EAGuingamp
# 2188            1904            199        Leicester City        @LCFC
# 2208            1905            201  West Bromwich Albion         @WBA
# 2225            1876            203            Stoke City   @stokecity
#
#         away_country_id  away_founded  away_venue_id league_type  \
# id
# 251728               17          1970            131    domestic
# 251738               17          1912           1715    domestic
# 2188                462          1884            117    domestic
# 2208                462          1878            119    domestic
# 2225                462          1868            207    domestic
#
#         league_country_id     league_name  league_is_cup season_name  \
# id
# 251728                 17         Ligue 1              0   2016/2017
# 251738                 17         Ligue 1              0   2016/2017
# 2188                  462  Premier League              0   2016/2017
# 2208                  462  Premier League              0   2016/2017
# 2225                  462  Premier League              0   2016/2017
#
#         round_name round_start  round_end           venue_name  \
# id
# 251728           1  2016-08-12 2016-08-14  Stade Armand-Césari
# 251738           1  2016-08-12 2016-08-14      Stade Louis II.
# 2188             1  2016-08-13 2016-08-15         KCOM Stadium
# 2208             1  2016-08-13 2016-08-15        Selhurst Park
# 2225             1  2016-08-13 2016-08-15    Riverside Stadium
#
#         venue_surface_isgrass     venue_city  venue_capacity  \
# id
# 251728                      1        Furiani           16078
# 251738                      1         Monaco           18523
# 2188                        1           Hull           25400
# 2208                        1         London           25073
# 2225                        1  Middlesbrough           34988
#
#             venue_coordinates    referee_fullname  homecoach_coach_id  \
# id
# 251728   (42.651400,9.442619)     Frank Schneider              896573
# 251738   (43.727606,7.415614)  Jérôme Miguelgorry              896525
# 2188    (53.746111,-0.367778)           Mike Dean              896472
# 2208    (51.398333,-0.085556)        Craig Pawson              896470
# 2225    (54.578333,-1.216944)        Kevin Friend              896473
#
#         homecoach_country_id                      homecoach_fullname  \
# id
# 251728                    17                      François Ciccolini
# 251738                    20  José Leonardo Nunes Alves Sousa Jardim
# 2188                     462                             Mike Phelan
# 2208                     462                             Alan Pardew
# 2225                      32                 Aitor Karanka de la Hoz
#
#        homecoach_nationality homecoach_birthdate homecoach_birthcountry  \
# id
# 251728                France          1962-06-03                 France
# 251738              Portugal          1974-08-01              Venezuela
# 2188                 England          1962-09-24                England
# 2208                 England          1961-07-18                England
# 2225                   Spain          1973-09-18                  Spain
#
#         awaycoach_coach_id  awaycoach_country_id    awaycoach_fullname  \
# id
# 251728              455907                    32  Unai Emery Etxegoien
# 251738              459054                    17     Antoine Kombouare
# 2188                893654                   251       Claudio Ranieri
# 2208                455360                   515            Tony Pulis
# 2225                455458                   515           Mark Hughes
#
#        awaycoach_nationality awaycoach_birthdate awaycoach_birthcountry  \
# id
# 251728                 Spain          1971-11-03                  Spain
# 251738                France          1963-11-16          New Caledonia
# 2188                   Italy          1951-10-20                  Italy
# 2208                   Wales          1958-01-16                  Wales
# 2225                   Wales          1963-11-01                  Wales
#
#        colors_home_color colors_away_color  result  goal_diff  \
# id
# 251728           #202A44           #F0F0F0       2         -1
# 251738           #C40010           #C40010       0          0
# 2188             #FC7E00           #B0E8E6       1          1
# 2208             #0046A8           #025C17       2         -1
# 2225             #C40010           #339063       0          0
#
#                       time        lat       lon  temp  cloudcover  humidity  \
# id
# 251728 2016-08-12 20:00:00  42.651400  9.442619  23.9          27        48
# 251738 2016-08-12 20:30:00  43.727606  7.415614  17.9          25        73
# 2188   2016-08-13 13:30:00  53.746111 -0.367778  20.2          54        62
# 2208   2016-08-13 16:00:00  51.398333 -0.085556  22.2          38        62
# 2225   2016-08-13 16:00:00  54.578333 -1.216944  19.0          63        61
#
#         pressure  visibility  winddir  windspeed  night_game  \
# id
# 251728      1022          30       21       3.06           1
# 251738      1014          10      312       0.92           1
# 2188        1014          10      315       3.36           0
# 2208        1022          43      243       4.28           0
# 2225        1019          39      279       7.39           0
#
#                    coord_away  travel_dist(km)
# id
# 251728   (48.841389,2.253056)              886
# 251738  (48.566285,-3.164599)              977
# 2188    (52.620278,-1.142222)              136
# 2208    (52.509068,-1.963892)              179
# 2225    (52.988419,-2.175398)              188

# %%
venue_data.to_csv('../../Data/Modeling_Before_Preparation/Venue_data_v01.csv')

# %% [markdown]
# ## *Team Attributes Data*

# %% [markdown]
# Import Teams' Attributes Data

# %%
# Data Import 
tm_attr = pd.read_csv('../../Data/From_Collection/FIFA_scraped/team_weekly_complete.csv', low_memory=False)
# ObservationDate format
date_replace = {'June': 'Jun.', 'Sept': 'Sep', 'April': 'Apr.', 'June': 'Jun.', 'March': 'Mar.', 'May': 'May.', 'July': 'Jul.'}
for key, value in date_replace.items():
    tm_attr['ObservationDate'] = tm_attr['ObservationDate'].str.replace(key, value)
tm_attr['ObservationDate'] = tm_attr['ObservationDate'].map(lambda x: datetime.strptime(x, '%b. %d, %Y'))
# Sort values + filter by date
tm_attr = tm_attr.sort_values(by = ['ObservationDate', 'TeamName'], ascending=True).reset_index(drop = True)
attr16 = tm_attr.loc[(tm_attr['ObservationDate'] > '2016-05-01'), :]
# Fill columns' NAs
columns_to_fill = ['Captain','Short Free Kick','Long Free Kick','Penalties','Left Corner','Right Corner']
for col in columns_to_fill:
    attr16[col] = attr16.groupby('TeamName')[col].fillna(method='bfill').fillna(method='ffill')
# Get Width column 
attr16['Width'] = np.where(attr16['Width'].isna(), attr16['Team Width'], attr16['Width'])
attr16['Width'] = np.where(attr16['Width'] >= 10, round(attr16['Width']/10), round(attr16['Width']))
# Filter columns
attr16 = attr16.loc[:, ['ObservationDate','TeamName','Attack','Midfield','Defence','TransferBudget','Width','is_major','RivalTeam','Captain','Short Free Kick','Long Free Kick','Penalties','Left Corner','Right Corner','TeamRoster','LoanedPlayers']]

# %% [markdown]
# Replace teams' names for consistency

# %%
# Teams Names from attr16 and replacement names 
teams_name_repl =  {'1. ': '', 'RC Deportivo de La Coruña': 'Deportivo La Coruña', 'RC Deportivo': 'Deportivo La Coruña', 'RC Celta de Vigo': 'RC Celta', 'RC Celta': 'Celta de Vigo','RC ': '', 'RCD ': '', ' Football Club SA': '', 'AS ': '', ' Football Club': '', ' Football': '', 'R.': 'Real', 'CD ': '', 'CF ': '', ' CF': '', 'CA ': '', ' FC': '', 'LOSC ': '', 'OGC ': '', 'AD ': '', 'Balompié': 'BP', ' BP': '', ' 63': '', 'SL ': '', 'Nancy-Lorraine': 'Nancy', 'Arminia Bielefeld': 'DSC Arminia Bielefeld', 'Athletic Club de Bilbao': 'Athletic Club', 'Atlético de Madrid': 'Atlético Madrid', 'Bergamo Calcio': 'Atalanta', "Borussia M'gladbach": 'Borussia Mönchengladbach', 'Bournemouth': 'AFC Bournemouth', 'Chievo Verona': 'Chievo', 'Clermont Foot': 'Clermont', 'D. Alavés': 'Deportivo Alavés', 'DijonO': 'Dijon', 'ES Troyes AC': 'Troyes', 'ESTAC Troyes': 'Troyes', 'En Avant de Guingamp': 'Guingamp', 'En Avant Guingamp': 'Guingamp', 'FC Bayern Munich': 'Bayern München', 'FC Bayern München': 'Bayern München','Bayern München': 'FC Bayern München', 'FC Girondins de Bordeaux': 'Bordeaux', 'Girondins de Bordeaux': 'Bordeaux', 'FC Ingolstadt 04': 'Ingolstadt', 'FC Lorient': 'Lorient', 'FC Metz': 'Metz', 'FC Nantes': 'Nantes', 'FC Nürnberg': 'Nürnberg', 'FC Schalke 04': 'Schalke 04',  'Football Club de Metz': 'Metz', 'Hertha BSC Berlin': 'Hertha BSC', 'Hertha Berlin': 'Hertha BSC', 'La Spezia': 'Spezia', 'Latium': 'Lazio', 'Levante UD': 'Levante', 'Montpellier HSC': 'Montpellier', 'Montpellier Hérault SC': 'Montpellier', 'Nîmes Olympique': 'Nîmes', 'Olympique de Marseille': 'Olympique Marseille', 'Paris Saint-Germain': 'Paris Saint Germain',  'Strasbourg Alsace': 'Strasbourg', 'Real Sporting de Gijón': 'Sporting Gijón', 'SC Bastia': 'Bastia', 'SC Paderborn 07': 'Paderborn', 'SD Huesca': 'Huesca', 'SM Caen': 'Caen', 'Stade Malherbe Caen': 'Caen', 'SV Darmstadt 98': 'Darmstadt 98', 'SV Werder Bremen': 'Werder Bremen', 'Spal': 'SPAL', 'Sport-Club Freiburg': 'SC Freiburg', 'Stade Brestois 29': 'Brest', 'Stade Rennais': 'Rennes', 'Stade de Reims': 'Reims', 'TSG 1899 Hoffenheim': 'TSG Hoffenheim', 'Toulouse Club': 'Toulouse', 'UD Las Palmas': 'Las Palmas', 'VfL Bochum': 'VfL Bochum 1848', 'Racing Club de Lens': 'Lens', 'Bilbao Athletic': 'Athletic Club', 'Salerno': 'Salernitana', 'Cádiz C.F.': 'Cádiz', 'Cremona': 'Cremonese', 'FC Porto': 'Porto', 'SD Ponferradina': 'Ponferradina', 'UD Almería': 'Almería', 'Reus': 'Reus Deportiu', 'Gimnàstic de Tarragona': 'Gimnàstic Tarragona', 'Vercelli': 'Pro Vercelli', 'Numancia de Soria': 'Numancia', 'Castellammare di Stabia': 'Juve Stabia', 'SD Amorebieta': 'Amorebieta', 'DSC DSC Arminia Bielefeld': 'DSC Arminia Bielefeld', 'AFC AFC Bournemouth': 'AFC Bournemouth', 'Nancy Lorraine': 'Nancy'}

# Substitute names using dictionary
for old, new in teams_name_repl.items():
    attr16['TeamName'] = attr16['TeamName'].str.replace(old, new, regex=False)
# Tests for names: if both OK continue with no problem
st_mask = static.loc[static['league_is_cup'] == 0, 'home_name']
attr_mask = attr16.loc[(attr16['is_major'] == 1) & (attr16['ObservationDate'] > '2016-09-28'), 'TeamName']
print('Static test: OK!') if not (set(st_mask) - set(attr16.loc[:, 'TeamName'])) else print(set(st_mask) - set(attr16.loc[:, 'TeamName']))
print('Attributes test: OK!') if not (set(attr_mask) - set(st_mask)) else print(set(attr_mask) - set(st_mask))
# Out:
# Static test: OK!
# Attributes test: OK!

# %% [markdown]
# Functions - for data merge

# %%
def test_merge(df, homeORaway):
    """This function tests whether the merger between DataFrames occurred correctly or not by comparing both teams names and dates. It prints how many observations are not consistently merged.
    df: dataframe to test
    homeORaway: either 'home' or 'away' are tested 
    """
    print('****** TEST ', homeORaway.upper(), ' ******')
    print('Name Errors = ', (df[homeORaway + '_name'] != df[homeORaway + '_TeamName']).sum())
    print('Date Errors = ', (df[homeORaway + '_ObservationDate'].dt.date > df['time_starting_at_date_time'].dt.date).sum())

# %%
def merge_list_dicts(original_df, list_of_dicts, prefix):
    """This function merges the provided original_df with a new_df created from a provided list of dictionaries (list_of_dicts), and also uses test_merge() to test the success of the merging operation.
    original_df: original dataframe 
    list_of_dicts: list of dictionaries to merge with original_df
    prefix: prefix added to columns created from list_of_dicts (either 'home' or 'away', if else the function prints a warning)
    """
    if prefix not in ['home', 'away']: # uncorrectly specified prefix
        print('Selected option is not possoble!! (Must be home or away)')
    else:
        new_df = pd.DataFrame(list_of_dicts).add_prefix(prefix + '_') # Create new home dataframe
        merged_df = pd.merge(original_df, new_df, how='outer', left_index=True, right_index=True) # Merge it with original_df
        test_merge(merged_df, prefix) # Test the operation
        return merged_df

# %%
def get_binaryrivals(df):
    df['isrival_home'] = np.where(df['away_name'] == df['home_RivalTeam'], 1, 0)
    df['isrival_away'] = np.where(df['home_name'] == df['away_RivalTeam'], 1, 0)
    df.drop(['home_RivalTeam', 'away_RivalTeam'], axis = 1, inplace=True)
    return df

# %% [markdown]
# Merge static and attr16

# %%
static_leagues = static_leagues.reset_index()

# Initial loop to consider both home and away teams
for h_a in ['home_name', 'away_name']:
    all_ordered = []
    for index, row in tqdm(static_leagues.iterrows(), total=static_leagues.shape[0]):
        mask_temp = attr16.loc[attr16['TeamName'] == row[h_a], :]
        if mask_temp.shape[0] == 0: dict_append = {}
        else:
            # Calculate the difference between all dates from static_leagues and attr16 datasets, only when the teams are the same (else 999)
            st_date = row['time_starting_at_date_time'].date()
            time_d = [(st_date - j.date()).days if (st_date - j.date()).days >= 0 else 999 for j in mask_temp.loc[:, 'ObservationDate']]
            index_found = min(range(len(time_d)), key=time_d.__getitem__) # Get closest date's index from time_d
            # In case the previous step was unsuccessful consider closest date but in the future
            if index_found == 0 and time_d[index_found] > 90:
                time_d_exrelegated = [(st_date - k.date()).days if (st_date - k.date()).days < 0 else -999 for k in mask_temp.loc[:, 'ObservationDate']]
                index_found = max(range(len(time_d_exrelegated)), key=time_d_exrelegated.__getitem__) # Get closest date index but posterior
            dict_append = dict(mask_temp.iloc[index_found,:])

        # Append dictionary of attributes data to list
        all_ordered.append(dict_append) # Append the row to a list

    # Merge list of dictionaries to initial dataframe
    if h_a == 'home_name':
        merge_home = merge_list_dicts(original_df=static_leagues, list_of_dicts=all_ordered, prefix='home')
    else:
        matchattr_l = merge_list_dicts(original_df=merge_home, list_of_dicts=all_ordered, prefix='away')
# Out:
# /Library/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   """Entry point for launching an IPython kernel.
#   0%|          | 0/10536 [00:00<?, ?it/s]
# ****** TEST  HOME  ******
# Name Errors =  0
# Date Errors =  2
#   0%|          | 0/10536 [00:00<?, ?it/s]
# ****** TEST  AWAY  ******
# Name Errors =  0
# Date Errors =  2

# %% [markdown]
# Results and Checks

# %%
# Concatenate resulting df of leagues' matches with attributes and df of cups' matches without attributes (should create NAs)
# matchattr_l = pd.concat([matchattr_l, static_cups], axis=0).sort_index()
# matchattr_l = matchattr_l.set_index('id')
# Test if concatenated properly, NAs for teams' attributes should be of the same lenght of static_cups data
print('Concatenate step is OK?', matchattr_l['home_TeamName'].isna().sum() == matchattr_l['away_TeamName'].isna().sum())
print('Are home and away dates perfectly equal?', (matchattr_l.loc[(~matchattr_l['home_ObservationDate'].isna()), 'home_ObservationDate'] != matchattr_l.loc[(~matchattr_l['away_ObservationDate'].isna()), 'away_ObservationDate']).sum() == 0)
# Out:
# Concatenate step is OK? True
# Are home and away dates perfectly equal? False

# %% [markdown]
# ###### **NOTES**: To avoid problems with teams coming from a minor league we consider the case of the index_min taking the value 0 and the team name from match data not matching the team name on tm_weekly16, in this case we consider the attributes of the right team but coming from the closest observation in the future (instead that from the past). This problem could be avoided through scraping also data from the minor leagues! **SOLVED SCRAPING MINOR LEAGUES TOO**

# %% [markdown]
# Filter Team Attributes Data

# %%
columns_team_at = matchattr_l.loc[:, :'colors_away_color'].columns.tolist() + ['result', 'goal_diff'] + \
    matchattr_l.loc[:, 'home_ObservationDate':].columns.tolist()
team_at = matchattr_l.loc[:, columns_team_at]
team_at = get_binaryrivals(team_at)
team_at.head()
# Out:
#        id  league_id  season_id  stage_id  venue_id  referee_id  home_id  \
# 0  251728        301        765      1392        37       15478      430
# 1  251738        301        765      1392      4451       11668     6789
# 2    2188          8         13        11       199       15241       22
# 3    2208          8         13        11       201       15293       51
# 4    2225          8         13        11       203       15242        7
#
#    away_id  winner_team_id  commentaries  attendance  \
# 0      591             591             1       13122
# 1     2919               0             1        8019
# 2       42              22             1       20137
# 3       10              10             1       24490
# 4       26               0             1       32110
#
#   formations_home_formation formations_away_formation  scores_home_score  \
# 0                   4-3-2-1                   4-2-3-1                  0
# 1                     4-4-2                   4-2-2-2                  2
# 2                     4-3-3                     4-4-2                  2
# 3                   4-2-3-1                     4-4-2                  0
# 4                   4-2-3-1                   4-2-3-1                  1
#
#    scores_away_score scores_ht_score scores_ft_score scores_et_score  \
# 0                  1             0-0             0-1             NaN
# 1                  2             0-2             2-2             NaN
# 2                  1             1-0             2-1             NaN
# 3                  1             0-0             0-1             NaN
# 4                  1             1-0             1-1             NaN
#
#   scores_ps_score time_starting_at_date_time time_starting_at_date  \
# 0             NaN        2016-08-12 20:00:00            2016-08-12
# 1             NaN        2016-08-12 20:30:00            2016-08-12
# 2             NaN        2016-08-13 13:30:00            2016-08-13
# 3             NaN        2016-08-13 16:00:00            2016-08-13
# 4             NaN        2016-08-13 16:00:00            2016-08-13
#
#   time_starting_at_timezone  time_minute  standings_home_position  \
# 0               Europe/Rome           90                     <NA>
# 1               Europe/Rome           90                     <NA>
# 2               Europe/Rome           90                     <NA>
# 3               Europe/Rome           90                     <NA>
# 4               Europe/Rome           90                     <NA>
#
#    standings_away_position       home_name home_twitter  home_country_id  \
# 0                     <NA>          Bastia    @SCBastia               17
# 1                     <NA>          Monaco   @AS_Monaco            75285
# 2                     <NA>       Hull City    @HullCity              462
# 3                     <NA>  Crystal Palace        @CPFC              462
# 4                     <NA>   Middlesbrough        @Boro              462
#
#    home_founded  home_venue_id             away_name away_twitter  \
# 0          1905             37   Paris Saint Germain  @PSG_inside
# 1          1919           4451              Guingamp  @EAGuingamp
# 2          1904            199        Leicester City        @LCFC
# 3          1905            201  West Bromwich Albion         @WBA
# 4          1876            203            Stoke City   @stokecity
#
#    away_country_id  away_founded  away_venue_id league_type  \
# 0               17          1970            131    domestic
# 1               17          1912           1715    domestic
# 2              462          1884            117    domestic
# 3              462          1878            119    domestic
# 4              462          1868            207    domestic
#
#    league_country_id     league_name  league_is_cup season_name  round_name  \
# 0                 17         Ligue 1              0   2016/2017           1
# 1                 17         Ligue 1              0   2016/2017           1
# 2                462  Premier League              0   2016/2017           1
# 3                462  Premier League              0   2016/2017           1
# 4                462  Premier League              0   2016/2017           1
#
#   round_start  round_end           venue_name  venue_surface_isgrass  \
# 0  2016-08-12 2016-08-14  Stade Armand-Césari                      1
# 1  2016-08-12 2016-08-14      Stade Louis II.                      1
# 2  2016-08-13 2016-08-15         KCOM Stadium                      1
# 3  2016-08-13 2016-08-15        Selhurst Park                      1
# 4  2016-08-13 2016-08-15    Riverside Stadium                      1
#
#       venue_city  venue_capacity      venue_coordinates    referee_fullname  \
# 0        Furiani           16078   (42.651400,9.442619)     Frank Schneider
# 1         Monaco           18523   (43.727606,7.415614)  Jérôme Miguelgorry
# 2           Hull           25400  (53.746111,-0.367778)           Mike Dean
# 3         London           25073  (51.398333,-0.085556)        Craig Pawson
# 4  Middlesbrough           34988  (54.578333,-1.216944)        Kevin Friend
#
#    homecoach_coach_id  homecoach_country_id  \
# 0              896573                    17
# 1              896525                    20
# 2              896472                   462
# 3              896470                   462
# 4              896473                    32
#
#                        homecoach_fullname homecoach_nationality  \
# 0                      François Ciccolini                France
# 1  José Leonardo Nunes Alves Sousa Jardim              Portugal
# 2                             Mike Phelan               England
# 3                             Alan Pardew               England
# 4                 Aitor Karanka de la Hoz                 Spain
#
#   homecoach_birthdate homecoach_birthcountry  awaycoach_coach_id  \
# 0          1962-06-03                 France              455907
# 1          1974-08-01              Venezuela              459054
# 2          1962-09-24                England              893654
# 3          1961-07-18                England              455360
# 4          1973-09-18                  Spain              455458
#
#    awaycoach_country_id    awaycoach_fullname awaycoach_nationality  \
# 0                    32  Unai Emery Etxegoien                 Spain
# 1                    17     Antoine Kombouare                France
# 2                   251       Claudio Ranieri                 Italy
# 3                   515            Tony Pulis                 Wales
# 4                   515           Mark Hughes                 Wales
#
#   awaycoach_birthdate awaycoach_birthcountry colors_home_color  \
# 0          1971-11-03                  Spain           #202A44
# 1          1963-11-16          New Caledonia           #C40010
# 2          1951-10-20                  Italy           #FC7E00
# 3          1958-01-16                  Wales           #0046A8
# 4          1963-11-01                  Wales           #C40010
#
#   colors_away_color  result  goal_diff home_ObservationDate   home_TeamName  \
# 0           #F0F0F0       2         -1           2016-06-09          Bastia
# 1           #C40010       0          0           2016-06-09          Monaco
# 2           #B0E8E6       1          1           2016-06-09       Hull City
# 3           #025C17       2         -1           2016-06-09  Crystal Palace
# 4           #339063       0          0           2016-06-09   Middlesbrough
#
#    home_Attack  home_Midfield  home_Defence  home_TransferBudget  home_Width  \
# 0           70             71            71              2800000         5.0
# 1           77             77            77             55000000         5.0
# 2           73             73            73             15000000         5.0
# 3           75             76            75             23500000         4.0
# 4           74             73            71              8000000         6.0
#
#    home_is_major home_Captain home_Short Free Kick home_Long Free Kick  \
# 0              1      Cahuzac                Ayité               Danic
# 1              1     Toulalan        João Moutinho       João Moutinho
# 2              0       Dawson            Snodgrass         Huddlestone
# 3              1      Delaney             Puncheon            Puncheon
# 4              0   Leadbitter              Ramírez             Clayton
#
#   home_Penalties home_Left Corner home_Right Corner  \
# 0          Ayité            Danic             Danic
# 1        Fabinho   Bernardo Silva             Lemar
# 2      Snodgrass        Snodgrass         Snodgrass
# 3        Wickham         Puncheon          Puncheon
# 4     Leadbitter       Leadbitter           Ramírez
#
#                                      home_TeamRoster  \
# 0  ['Jean-Louis Leca', 'Gilles Cioni', 'Sébastien...
# 1  ['Danijel Subašić', 'Fabinho', 'WallaceL', 'Ri...
# 2  ['Eldin Jakupović', 'Moses Odubajo', 'Michael ...
# 3  ['Wayne Hennessey', 'Joel Ward', 'Scott Dann',...
# 4  ['Dimitrios Konstantopoulos', 'Nsue', 'Daniel ...
#
#                                   home_LoanedPlayers away_ObservationDate  \
# 0                                                 []           2016-06-09
# 1  ['Falcao', 'Valère Germain', 'Marcos Lopes', "...           2016-06-09
# 2                                                 []           2016-06-09
# 3                                                 []           2016-06-09
# 4                                                 []           2016-06-09
#
#           away_TeamName  away_Attack  away_Midfield  away_Defence  \
# 0   Paris Saint Germain           84             82            82
# 1              Guingamp           73             73            72
# 2        Leicester City           76             77            75
# 3  West Bromwich Albion           76             73            73
# 4            Stoke City           76             78            76
#
#    away_TransferBudget  away_Width  away_is_major  away_Captain  \
# 0            100000000         6.0              1  Thiago Silva
# 1              3200000         5.0              1       Giresse
# 2             27000000         4.0              1        Morgan
# 3             22000000         5.0              1      Fletcher
# 4             30000000         5.0              1     Shawcross
#
#   away_Short Free Kick away_Long Free Kick away_Penalties away_Left Corner  \
# 0          Ibrahimović         Ibrahimović    Ibrahimović         Di María
# 1              Salibur             Salibur         Briand          Salibur
# 2               Mahrez              Mahrez          Vardy           Mahrez
# 3              McClean             McClean        Gardner          McClean
# 4           Arnautović          Arnautović          Bojan       Arnautović
#
#   away_Right Corner                                    away_TeamRoster  \
# 0          Di María  ['Kevin Trapp', 'Serge Aurier', 'Thiago Silva'...
# 1           Salibur  ['Jonas Lössl', 'Jonathan Martins Pereira', 'C...
# 2             Fuchs  ['Kasper Schmeichel', 'Danny Simpson', 'Wes Mo...
# 3           McClean  ['Ben Foster', 'Craig Dawson', 'Gareth McAuley...
# 4        Arnautović  ['Jakob Haugaard', 'Phil Bardsley', 'Ryan Shaw...
#
#                                   away_LoanedPlayers  isrival_home  \
# 0  ['Alphonse Aréola', 'Lucas Digne', 'Youssouf S...             0
# 1  ['Ronnie Schwartz', 'Rachid Alioui', 'Baïssama...             0
# 2                               ['Yohan Benalouane']             0
# 3                                                 []             0
# 4                                                 []             0
#
#    isrival_away
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %% [markdown]
# ## *Rest Data*

# %% [markdown]
# #### Functions

# %% [markdown]
# Number of observation last n days

# %%
def number_observation_last_n_days(items, pivot, n):
    """This function returns, for an iterable object items, the number of date elements that are previous to the pivot date and contained in a n day range. 

    items: iterable containg datetime elements
    pivot: datetime value
    n: max value of past days (range is between pivot and [pivot - n] days)
    """
    return len([i for i in items if i < pivot and (pivot-i).days <= n])

def games_last_n_days(df, num_days_list=[60, 30, 15, 7]):
    """This function creates new columns in the given DataFrame (df) by computing the number of games played by both the home and away team in the last n days (num_days_list). The parameter num_days_list has default values ([60, 30, 15, 7]), that could be differently specified. 

    df: dataframe to add new columns
    num_days_list (Default: [60, 30, 15, 7]): list of the number of past days to consider when looking at previous matches
    """
    for elem in tqdm(list(product(['home_', 'away_'], num_days_list)), desc='New columns in games_last_n_days()', unit='New col.'):
        tqdm.pandas(desc=('Games over last ' + str(elem[1]) + ' days for ' + elem[0]))
        df.loc[:, elem[0] + 'n_games_last' + str(elem[1]) + 'd'] = df.progress_apply(lambda x: number_observation_last_n_days(\
            items = df.loc[((x[elem[0] + 'id'] == df['home_id']) | (x[elem[0] + 'id'] == df['away_id'])), 'time_starting_at_date'],\
                pivot = x['time_starting_at_date'], n=elem[1]), axis=1)
    return df

# %% [markdown]
# Rest days

# %%
def days_differential_nearest_previous_date(items, pivot):
    """This function returns, for an iterable object items, the minimum days distance between any element of items previous to pivot, and pivot date value. 

    items: iterable containg datetime elements
    pivot: datetime value
    """
    return min([abs((i - pivot).days) for i in items if i < pivot], default=999)

def rest_days_columns(df):
    """This function creates 2 new columns (one for home team and one for away team) in the given DataFrame (df) by computing the  days differential (rest days) between the considered game and the previous one.

    df: dataframe to add new columns
    """
    for team in tqdm(['home_', 'away_'], desc='New columns in rest_days_columns()', unit='New col.'):
        tqdm.pandas(desc=('Rest days for ' + team))
        df.loc[:, team + 'rest_days'] = df.progress_apply(lambda x: days_differential_nearest_previous_date(
          items = df.loc[((x[team + 'id'] == df['home_id']) | (x[team + 'id'] == df['away_id'])), 'time_starting_at_date'], 
          pivot = x['time_starting_at_date']), axis=1)
    return df

# %% [markdown]
# #### New Features

# %%
# Mask DataFrame
static = static.set_index('id')
musk = static.loc[:, ['home_id', 'away_id', 'home_name', 'away_name', 'time_starting_at_date', 'league_is_cup']]
musk[musk.select_dtypes(['object']).columns] = musk.select_dtypes(['object']).apply(lambda x: x.astype('category'))
# Games over previous n days
musk = games_last_n_days(musk)
# Rest days
musk = rest_days_columns(musk)
# Remove outliers in rest days
musk.loc[:, 'home_rest_days'] = np.where(musk.loc[:, 'home_rest_days'] < 30, musk.loc[:, 'home_rest_days'], 30)
musk.loc[:, 'away_rest_days'] = np.where(musk.loc[:, 'away_rest_days'] < 30, musk.loc[:, 'away_rest_days'], 30)
# DataFrame datatypes
musk[musk.select_dtypes(np.number).columns] = musk.select_dtypes(np.number).apply(lambda x: x.astype(int))
musk.head(2)
# Out:
# New columns in games_last_n_days():   0%|          | 0/8 [00:00<?, ?New col./s]
# Games over last 60 days for home_:   0%|          | 0/23483 [00:00<?, ?it/s]
# Games over last 30 days for home_:   0%|          | 0/23483 [00:00<?, ?it/s]
# Games over last 15 days for home_:   0%|          | 0/23483 [00:00<?, ?it/s]
# Games over last 7 days for home_:   0%|          | 0/23483 [00:00<?, ?it/s]
# Games over last 60 days for away_:   0%|          | 0/23483 [00:00<?, ?it/s]
# Games over last 30 days for away_:   0%|          | 0/23483 [00:00<?, ?it/s]
# Games over last 15 days for away_:   0%|          | 0/23483 [00:00<?, ?it/s]
# Games over last 7 days for away_:   0%|          | 0/23483 [00:00<?, ?it/s]
# New columns in rest_days_columns():   0%|          | 0/2 [00:00<?, ?New col./s]
# Rest days for home_:   0%|          | 0/23483 [00:00<?, ?it/s]
# Rest days for away_:   0%|          | 0/23483 [00:00<?, ?it/s]
#          home_id  away_id home_name         away_name time_starting_at_date  \
# id
# 1062005     8643      579       B36    The New Saints            2015-07-01
# 1067032     7345      589  Ordabasy  Beitar Jerusalem            2015-07-02
#
#          league_is_cup  home_n_games_last60d  home_n_games_last30d  \
# id
# 1062005              1                     0                     0
# 1067032              1                     0                     0
#
#          home_n_games_last15d  home_n_games_last7d  away_n_games_last60d  \
# id
# 1062005                     0                    0                     0
# 1067032                     0                    0                     0
#
#          away_n_games_last30d  away_n_games_last15d  away_n_games_last7d  \
# id
# 1062005                     0                     0                    0
# 1067032                     0                     0                    0
#
#          home_rest_days  away_rest_days
# id
# 1062005              30              30
# 1067032              30              30

# %%
team_attr_rest = pd.merge(team_at.set_index('id'), musk, how='left', left_index=True, right_index=True, suffixes=[None, '_extra'])
team_attr_rest.drop(columns=team_attr_rest.filter(regex='_extra$').columns.tolist(), inplace=True)
print(team_attr_rest.shape)
team_attr_rest.head(2)
# Out:
# (10536, 108)
#         league_id  season_id  stage_id  venue_id  referee_id  home_id  \
# id
# 251728        301        765      1392        37       15478      430
# 251738        301        765      1392      4451       11668     6789
#
#         away_id  winner_team_id  commentaries  attendance  \
# id
# 251728      591             591             1       13122
# 251738     2919               0             1        8019
#
#        formations_home_formation formations_away_formation  scores_home_score  \
# id
# 251728                   4-3-2-1                   4-2-3-1                  0
# 251738                     4-4-2                   4-2-2-2                  2
#
#         scores_away_score scores_ht_score scores_ft_score scores_et_score  \
# id
# 251728                  1             0-0             0-1             NaN
# 251738                  2             0-2             2-2             NaN
#
#        scores_ps_score time_starting_at_date_time time_starting_at_date  \
# id
# 251728             NaN        2016-08-12 20:00:00            2016-08-12
# 251738             NaN        2016-08-12 20:30:00            2016-08-12
#
#        time_starting_at_timezone  time_minute  standings_home_position  \
# id
# 251728               Europe/Rome           90                     <NA>
# 251738               Europe/Rome           90                     <NA>
#
#         standings_away_position home_name home_twitter  home_country_id  \
# id
# 251728                     <NA>    Bastia    @SCBastia               17
# 251738                     <NA>    Monaco   @AS_Monaco            75285
#
#         home_founded  home_venue_id            away_name away_twitter  \
# id
# 251728          1905             37  Paris Saint Germain  @PSG_inside
# 251738          1919           4451             Guingamp  @EAGuingamp
#
#         away_country_id  away_founded  away_venue_id league_type  \
# id
# 251728               17          1970            131    domestic
# 251738               17          1912           1715    domestic
#
#         league_country_id league_name  league_is_cup season_name  round_name  \
# id
# 251728                 17     Ligue 1              0   2016/2017           1
# 251738                 17     Ligue 1              0   2016/2017           1
#
#        round_start  round_end           venue_name  venue_surface_isgrass  \
# id
# 251728  2016-08-12 2016-08-14  Stade Armand-Césari                      1
# 251738  2016-08-12 2016-08-14      Stade Louis II.                      1
#
#        venue_city  venue_capacity     venue_coordinates    referee_fullname  \
# id
# 251728    Furiani           16078  (42.651400,9.442619)     Frank Schneider
# 251738     Monaco           18523  (43.727606,7.415614)  Jérôme Miguelgorry
#
#         homecoach_coach_id  homecoach_country_id  \
# id
# 251728              896573                    17
# 251738              896525                    20
#
#                             homecoach_fullname homecoach_nationality  \
# id
# 251728                      François Ciccolini                France
# 251738  José Leonardo Nunes Alves Sousa Jardim              Portugal
#
#        homecoach_birthdate homecoach_birthcountry  awaycoach_coach_id  \
# id
# 251728          1962-06-03                 France              455907
# 251738          1974-08-01              Venezuela              459054
#
#         awaycoach_country_id    awaycoach_fullname awaycoach_nationality  \
# id
# 251728                    32  Unai Emery Etxegoien                 Spain
# 251738                    17     Antoine Kombouare                France
#
#        awaycoach_birthdate awaycoach_birthcountry colors_home_color  \
# id
# 251728          1971-11-03                  Spain           #202A44
# 251738          1963-11-16          New Caledonia           #C40010
#
#        colors_away_color  result  goal_diff home_ObservationDate  \
# id
# 251728           #F0F0F0       2         -1           2016-06-09
# 251738           #C40010       0          0           2016-06-09
#
#        home_TeamName  home_Attack  home_Midfield  home_Defence  \
# id
# 251728        Bastia           70             71            71
# 251738        Monaco           77             77            77
#
#         home_TransferBudget  home_Width  home_is_major home_Captain  \
# id
# 251728              2800000         5.0              1      Cahuzac
# 251738             55000000         5.0              1     Toulalan
#
#        home_Short Free Kick home_Long Free Kick home_Penalties  \
# id
# 251728                Ayité               Danic          Ayité
# 251738        João Moutinho       João Moutinho        Fabinho
#
#        home_Left Corner home_Right Corner  \
# id
# 251728            Danic             Danic
# 251738   Bernardo Silva             Lemar
#
#                                           home_TeamRoster  \
# id
# 251728  ['Jean-Louis Leca', 'Gilles Cioni', 'Sébastien...
# 251738  ['Danijel Subašić', 'Fabinho', 'WallaceL', 'Ri...
#
#                                        home_LoanedPlayers  \
# id
# 251728                                                 []
# 251738  ['Falcao', 'Valère Germain', 'Marcos Lopes', "...
#
#        away_ObservationDate        away_TeamName  away_Attack  away_Midfield  \
# id
# 251728           2016-06-09  Paris Saint Germain           84             82
# 251738           2016-06-09             Guingamp           73             73
#
#         away_Defence  away_TransferBudget  away_Width  away_is_major  \
# id
# 251728            82            100000000         6.0              1
# 251738            72              3200000         5.0              1
#
#         away_Captain away_Short Free Kick away_Long Free Kick away_Penalties  \
# id
# 251728  Thiago Silva          Ibrahimović         Ibrahimović    Ibrahimović
# 251738       Giresse              Salibur             Salibur         Briand
#
#        away_Left Corner away_Right Corner  \
# id
# 251728         Di María          Di María
# 251738          Salibur           Salibur
#
#                                           away_TeamRoster  \
# id
# 251728  ['Kevin Trapp', 'Serge Aurier', 'Thiago Silva'...
# 251738  ['Jonas Lössl', 'Jonathan Martins Pereira', 'C...
#
#                                        away_LoanedPlayers  isrival_home  \
# id
# 251728  ['Alphonse Aréola', 'Lucas Digne', 'Youssouf S...             0
# 251738  ['Ronnie Schwartz', 'Rachid Alioui', 'Baïssama...             0
#
#         isrival_away  home_n_games_last60d  home_n_games_last30d  \
# id
# 251728             0                     0                     0
# 251738             0                     2                     2
#
#         home_n_games_last15d  home_n_games_last7d  away_n_games_last60d  \
# id
# 251728                     0                    0                     0
# 251738                     1                    0                     0
#
#         away_n_games_last30d  away_n_games_last15d  away_n_games_last7d  \
# id
# 251728                     0                     0                    0
# 251738                     0                     0                    0
#
#         home_rest_days  away_rest_days
# id
# 251728              30              30
# 251738               9              30

# %%
team_attr_rest.to_csv('../../Data/Modeling_Before_Preparation/Team_attributes_and_Rest_data_v01.csv')

# %% [markdown]
# ## *Form Data*

# %% [markdown]
# Functions

# %%
def rename_columns_to_team(df):
    """This function returns a DataFrame, after replacing the substrings 'home' and 'away' with the substring 'team' in all columns' names.

    df: DataFrame
    """
    renamed_df = df.rename(columns={old_name: (re.sub(r'(home|away)', 'team', old_name)) for old_name in df.columns})
    return renamed_df

# %%
def avg_value_n_closest_dates(df, date_col, value_col, n_size):
    """Given a DataFrame, a column and a integer n; this function returns the average for the specified column in the DataFrame of the last (considering precedent and closest dates) n_size number of values.

    df: DataFrame
    date_col: column in df which contains dates values
    value_col: column of values to average from
    n_size: number of last values (in date) 
    """
    return np.mean(df.loc[df[date_col].nlargest(n=n_size, keep='last').index, value_col])
    
def avg_new_features(df, list_features, list_n_games, suffix_new_columns=''):
    """This function adds new columns to the provided DataFrame, containing the features in list_features averaged on the last n past observation contained in list_n_games.
    
    df: DataFrame
    list_features: list of features for new form features
    list_n_games: list for numbers of last matches to consider from
    """
    for elem in tqdm(list(product(list_features, list_n_games))):
        # tqdm.pandas(desc=(elem[0] + ' over the last ' + str(elem[1]) + ' games')) --> progress_apply()
        team_id = 'home_id' if 'home' in elem[0] else 'away_id' if 'away' in elem[0] else 'team_id' if 'team' in elem[0] else Exception(ValueError)
        # Apply avg_value_n_closest_dates by row
        df.loc[:, elem[0] + '_last' + str(elem[1]) + '_games' + suffix_new_columns] = df.apply(lambda x: avg_value_n_closest_dates(\
                df = df.loc[((x[team_id] == df[team_id]) & (x['time_starting_at_date'] > df['time_starting_at_date'])), :], date_col = 'time_starting_at_date', value_col = elem[0], n_size=elem[1]), axis=1)
                
    return df

# %% [markdown]
# Data Preparation

# %%
mask_form = static.loc[:, ['home_id','away_id','time_starting_at_date','league_is_cup','result','scores_home_score','scores_away_score']]
# Rename score columns
mask_form.rename(columns={'scores_home_score': 'home_goals_scored', 'scores_away_score': 'away_goals_scored'}, inplace=True)
# Point's columns for both home and away team from result column
mask_form['home_points'] = mask_form['result'].map({0:1, 1:3, 2:0})
mask_form['away_points'] = mask_form['result'].map({0:1, 1:0, 2:3})
# New goals conceded columns for both home and away 
mask_form['home_goals_conceded'] = mask_form['away_goals_scored']
mask_form['away_goals_conceded'] = mask_form['home_goals_scored']
# Home & Away goals differential columns
mask_form['home_goals_diff'] = mask_form['home_goals_scored'] - mask_form['home_goals_conceded']
mask_form['away_goals_diff'] = mask_form['away_goals_scored'] - mask_form['away_goals_conceded']
# Downcast numeric columns (integers)
mask_form[mask_form.select_dtypes(np.number).columns] = mask_form.select_dtypes(np.number).apply(pd.to_numeric, errors='coerce', downcast='integer')
mask_form.tail(2)
# Out:
#           home_id  away_id time_starting_at_date  league_is_cup  result  \
# id
# 18165743      594      485            2022-04-15              0       0
# 18157344      598     6789            2022-04-15              0       2
#
#           home_goals_scored  away_goals_scored  home_points  away_points  \
# id
# 18165743                  0                  0            1            1
# 18157344                  2                  3            0            3
#
#           home_goals_conceded  away_goals_conceded  home_goals_diff  \
# id
# 18165743                    0                    0                0
# 18157344                    3                    2               -1
#
#           away_goals_diff
# id
# 18165743                0
# 18157344                1

# %%
# Mask home teams 
mask_home = rename_columns_to_team(mask_form.loc[:, ['home_id', 'time_starting_at_date', 'league_is_cup', 'home_points', 'home_goals_scored', 'home_goals_conceded', 'home_goals_diff']])
# Mask away teams 
mask_away = rename_columns_to_team(mask_form.loc[:, ['away_id', 'time_starting_at_date', 'league_is_cup', 'away_points', 'away_goals_scored', 'away_goals_conceded', 'away_goals_diff']])
# Concatenate vertically mask_home and mask_away (avoided problem of using separate home and away IDs by using a team ID)
mask_form_teams = pd.concat([mask_home, mask_away], ignore_index=True).sort_values('time_starting_at_date').reset_index(drop=True)
print(mask_form_teams.shape)
mask_form_teams.head(2)
# Out:
# (46966, 7)
#    team_id time_starting_at_date  league_is_cup  team_points  \
# 0     8643            2015-07-01              1            0
# 1      579            2015-07-01              1            3
#
#    team_goals_scored  team_goals_conceded  team_goals_diff
# 0                  1                    2               -1
# 1                  2                    1                1

# %% [markdown]
# For only home & only away

# %%
list_number_games = [1, 3, 5, 10, 20] # List of n. games to consider

# %%
feats = ['home_points','away_points','home_goals_scored','away_goals_scored','home_goals_conceded','away_goals_conceded','home_goals_diff','away_goals_diff'] # list of features
# Only home and away WITH CUPS
mask_form = avg_new_features(df=mask_form, list_features=feats, list_n_games=list_number_games, suffix_new_columns='_withcups')
# Only home and away NO CUPS. Since we are only interested with cups data there is no need to create two different DataFrames and then merge them to preserve the data where league_is_cup == 0. (OK to filter out cups data)
mask_form_nocups = mask_form.loc[mask_form['league_is_cup'] == 0, :]
mask_form_nocups = avg_new_features(df=mask_form_nocups, list_features=feats, list_n_games=list_number_games, \
    suffix_new_columns='_nopcups')
# Print some info
print(mask_form_nocups.shape)
mask_form_nocups.head(3)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
#   0%|          | 0/40 [00:00<?, ?it/s]
# (12362, 93)
#         home_id  away_id time_starting_at_date  league_is_cup  result  \
# id
# 251711      690      591            2015-08-07              0       2
# 849          14        6            2015-08-08              0       1
# 864          33       51            2015-08-08              0       2
#
#         home_goals_scored  away_goals_scored  home_points  away_points  \
# id
# 251711                  0                  1            0            3
# 849                     1                  0            3            0
# 864                     1                  3            0            3
#
#         home_goals_conceded  away_goals_conceded  home_goals_diff  \
# id
# 251711                    1                    0               -1
# 849                       0                    1                1
# 864                       3                    1               -2
#
#         away_goals_diff  home_points_last1_games_withcups  \
# id
# 251711                1                               NaN
# 849                  -1                               NaN
# 864                   2                               NaN
#
#         home_points_last3_games_withcups  home_points_last5_games_withcups  \
# id
# 251711                               NaN                               NaN
# 849                                  NaN                               NaN
# 864                                  NaN                               NaN
#
#         home_points_last10_games_withcups  home_points_last20_games_withcups  \
# id
# 251711                                NaN                                NaN
# 849                                   NaN                                NaN
# 864                                   NaN                                NaN
#
#         away_points_last1_games_withcups  away_points_last3_games_withcups  \
# id
# 251711                               NaN                               NaN
# 849                                  NaN                               NaN
# 864                                  NaN                               NaN
#
#         away_points_last5_games_withcups  away_points_last10_games_withcups  \
# id
# 251711                               NaN                                NaN
# 849                                  NaN                                NaN
# 864                                  NaN                                NaN
#
#         away_points_last20_games_withcups  \
# id
# 251711                                NaN
# 849                                   NaN
# 864                                   NaN
#
#        home_goals_scored_last1_games_withcups  \
# id
# 251711                                   <NA>
# 849                                      <NA>
# 864                                      <NA>
#
#        home_goals_scored_last3_games_withcups  \
# id
# 251711                                   <NA>
# 849                                      <NA>
# 864                                      <NA>
#
#        home_goals_scored_last5_games_withcups  \
# id
# 251711                                   <NA>
# 849                                      <NA>
# 864                                      <NA>
#
#        home_goals_scored_last10_games_withcups  \
# id
# 251711                                    <NA>
# 849                                       <NA>
# 864                                       <NA>
#
#        home_goals_scored_last20_games_withcups  \
# id
# 251711                                    <NA>
# 849                                       <NA>
# 864                                       <NA>
#
#        away_goals_scored_last1_games_withcups  \
# id
# 251711                                   <NA>
# 849                                      <NA>
# 864                                      <NA>
#
#        away_goals_scored_last3_games_withcups  \
# id
# 251711                                   <NA>
# 849                                      <NA>
# 864                                      <NA>
#
#        away_goals_scored_last5_games_withcups  \
# id
# 251711                                   <NA>
# 849                                      <NA>
# 864                                      <NA>
#
#        away_goals_scored_last10_games_withcups  \
# id
# 251711                                    <NA>
# 849                                       <NA>
# 864                                       <NA>
#
#        away_goals_scored_last20_games_withcups  \
# id
# 251711                                    <NA>
# 849                                       <NA>
# 864                                       <NA>
#
#        home_goals_conceded_last1_games_withcups  \
# id
# 251711                                     <NA>
# 849                                        <NA>
# 864                                        <NA>
#
#        home_goals_conceded_last3_games_withcups  \
# id
# 251711                                     <NA>
# 849                                        <NA>
# 864                                        <NA>
#
#        home_goals_conceded_last5_games_withcups  \
# id
# 251711                                     <NA>
# 849                                        <NA>
# 864                                        <NA>
#
#        home_goals_conceded_last10_games_withcups  \
# id
# 251711                                      <NA>
# 849                                         <NA>
# 864                                         <NA>
#
#        home_goals_conceded_last20_games_withcups  \
# id
# 251711                                      <NA>
# 849                                         <NA>
# 864                                         <NA>
#
#        away_goals_conceded_last1_games_withcups  \
# id
# 251711                                     <NA>
# 849                                        <NA>
# 864                                        <NA>
#
#        away_goals_conceded_last3_games_withcups  \
# id
# 251711                                     <NA>
# 849                                        <NA>
# 864                                        <NA>
#
#        away_goals_conceded_last5_games_withcups  \
# id
# 251711                                     <NA>
# 849                                        <NA>
# 864                                        <NA>
#
#        away_goals_conceded_last10_games_withcups  \
# id
# 251711                                      <NA>
# 849                                         <NA>
# 864                                         <NA>
#
#        away_goals_conceded_last20_games_withcups  \
# id
# 251711                                      <NA>
# 849                                         <NA>
# 864                                         <NA>
#
#        home_goals_diff_last1_games_withcups  \
# id
# 251711                                 <NA>
# 849                                    <NA>
# 864                                    <NA>
#
#        home_goals_diff_last3_games_withcups  \
# id
# 251711                                 <NA>
# 849                                    <NA>
# 864                                    <NA>
#
#        home_goals_diff_last5_games_withcups  \
# id
# 251711                                 <NA>
# 849                                    <NA>
# 864                                    <NA>
#
#        home_goals_diff_last10_games_withcups  \
# id
# 251711                                  <NA>
# 849                                     <NA>
# 864                                     <NA>
#
#        home_goals_diff_last20_games_withcups  \
# id
# 251711                                  <NA>
# 849                                     <NA>
# 864                                     <NA>
#
#        away_goals_diff_last1_games_withcups  \
# id
# 251711                                 <NA>
# 849                                    <NA>
# 864                                    <NA>
#
#        away_goals_diff_last3_games_withcups  \
# id
# 251711                                 <NA>
# 849                                    <NA>
# 864                                    <NA>
#
#        away_goals_diff_last5_games_withcups  \
# id
# 251711                                 <NA>
# 849                                    <NA>
# 864                                    <NA>
#
#        away_goals_diff_last10_games_withcups  \
# id
# 251711                                  <NA>
# 849                                     <NA>
# 864                                     <NA>
#
#        away_goals_diff_last20_games_withcups  home_points_last1_games_nopcups  \
# id
# 251711                                  <NA>                              NaN
# 849                                     <NA>                              NaN
# 864                                     <NA>                              NaN
#
#         home_points_last3_games_nopcups  home_points_last5_games_nopcups  \
# id
# 251711                              NaN                              NaN
# 849                                 NaN                              NaN
# 864                                 NaN                              NaN
#
#         home_points_last10_games_nopcups  home_points_last20_games_nopcups  \
# id
# 251711                               NaN                               NaN
# 849                                  NaN                               NaN
# 864                                  NaN                               NaN
#
#         away_points_last1_games_nopcups  away_points_last3_games_nopcups  \
# id
# 251711                              NaN                              NaN
# 849                                 NaN                              NaN
# 864                                 NaN                              NaN
#
#         away_points_last5_games_nopcups  away_points_last10_games_nopcups  \
# id
# 251711                              NaN                               NaN
# 849                                 NaN                               NaN
# 864                                 NaN                               NaN
#
#         away_points_last20_games_nopcups  \
# id
# 251711                               NaN
# 849                                  NaN
# 864                                  NaN
#
#        home_goals_scored_last1_games_nopcups  \
# id
# 251711                                  <NA>
# 849                                     <NA>
# 864                                     <NA>
#
#        home_goals_scored_last3_games_nopcups  \
# id
# 251711                                  <NA>
# 849                                     <NA>
# 864                                     <NA>
#
#        home_goals_scored_last5_games_nopcups  \
# id
# 251711                                  <NA>
# 849                                     <NA>
# 864                                     <NA>
#
#        home_goals_scored_last10_games_nopcups  \
# id
# 251711                                   <NA>
# 849                                      <NA>
# 864                                      <NA>
#
#        home_goals_scored_last20_games_nopcups  \
# id
# 251711                                   <NA>
# 849                                      <NA>
# 864                                      <NA>
#
#        away_goals_scored_last1_games_nopcups  \
# id
# 251711                                  <NA>
# 849                                     <NA>
# 864                                     <NA>
#
#        away_goals_scored_last3_games_nopcups  \
# id
# 251711                                  <NA>
# 849                                     <NA>
# 864                                     <NA>
#
#        away_goals_scored_last5_games_nopcups  \
# id
# 251711                                  <NA>
# 849                                     <NA>
# 864                                     <NA>
#
#        away_goals_scored_last10_games_nopcups  \
# id
# 251711                                   <NA>
# 849                                      <NA>
# 864                                      <NA>
#
#        away_goals_scored_last20_games_nopcups  \
# id
# 251711                                   <NA>
# 849                                      <NA>
# 864                                      <NA>
#
#        home_goals_conceded_last1_games_nopcups  \
# id
# 251711                                    <NA>
# 849                                       <NA>
# 864                                       <NA>
#
#        home_goals_conceded_last3_games_nopcups  \
# id
# 251711                                    <NA>
# 849                                       <NA>
# 864                                       <NA>
#
#        home_goals_conceded_last5_games_nopcups  \
# id
# 251711                                    <NA>
# 849                                       <NA>
# 864                                       <NA>
#
#        home_goals_conceded_last10_games_nopcups  \
# id
# 251711                                     <NA>
# 849                                        <NA>
# 864                                        <NA>
#
#        home_goals_conceded_last20_games_nopcups  \
# id
# 251711                                     <NA>
# 849                                        <NA>
# 864                                        <NA>
#
#        away_goals_conceded_last1_games_nopcups  \
# id
# 251711                                    <NA>
# 849                                       <NA>
# 864                                       <NA>
#
#        away_goals_conceded_last3_games_nopcups  \
# id
# 251711                                    <NA>
# 849                                       <NA>
# 864                                       <NA>
#
#        away_goals_conceded_last5_games_nopcups  \
# id
# 251711                                    <NA>
# 849                                       <NA>
# 864                                       <NA>
#
#        away_goals_conceded_last10_games_nopcups  \
# id
# 251711                                     <NA>
# 849                                        <NA>
# 864                                        <NA>
#
#        away_goals_conceded_last20_games_nopcups  \
# id
# 251711                                     <NA>
# 849                                        <NA>
# 864                                        <NA>
#
#        home_goals_diff_last1_games_nopcups  \
# id
# 251711                                <NA>
# 849                                   <NA>
# 864                                   <NA>
#
#        home_goals_diff_last3_games_nopcups  \
# id
# 251711                                <NA>
# 849                                   <NA>
# 864                                   <NA>
#
#        home_goals_diff_last5_games_nopcups  \
# id
# 251711                                <NA>
# 849                                   <NA>
# 864                                   <NA>
#
#        home_goals_diff_last10_games_nopcups  \
# id
# 251711                                 <NA>
# 849                                    <NA>
# 864                                    <NA>
#
#        home_goals_diff_last20_games_nopcups  \
# id
# 251711                                 <NA>
# 849                                    <NA>
# 864                                    <NA>
#
#        away_goals_diff_last1_games_nopcups  \
# id
# 251711                                <NA>
# 849                                   <NA>
# 864                                   <NA>
#
#        away_goals_diff_last3_games_nopcups  \
# id
# 251711                                <NA>
# 849                                   <NA>
# 864                                   <NA>
#
#        away_goals_diff_last5_games_nopcups  \
# id
# 251711                                <NA>
# 849                                   <NA>
# 864                                   <NA>
#
#        away_goals_diff_last10_games_nopcups  \
# id
# 251711                                 <NA>
# 849                                    <NA>
# 864                                    <NA>
#
#        away_goals_diff_last20_games_nopcups
# id
# 251711                                 <NA>
# 849                                    <NA>
# 864                                    <NA>

# %% [markdown]
# Both home and away games

# %%
list_feats2 = ['team_points', 'team_goals_scored', 'team_goals_conceded', 'team_goals_diff']
# Both home and away WITH CUPS
mask_form_teams = avg_new_features(df=mask_form_teams, list_features=list_feats2, list_n_games=list_number_games, \
    suffix_new_columns='_withcups')
# Both home and away NO CUPS
mask_form_teams_nocups = mask_form_teams.loc[mask_form_teams['league_is_cup'] == 0, :]
mask_form_teams_nocups = avg_new_features(df=mask_form_teams_nocups, list_features=list_feats2, list_n_games=list_number_games, \
    suffix_new_columns='_nopcups')
# Print some info
print(mask_form_teams_nocups.shape)
mask_form_teams_nocups.tail(3)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# (24724, 47)
#        team_id time_starting_at_date  league_is_cup  team_points  \
# 46963      345            2022-04-15              0            0
# 46964      485            2022-04-15              0            1
# 46965     6789            2022-04-15              0            3
#
#        team_goals_scored  team_goals_conceded  team_goals_diff  \
# 46963                  1                    3               -2
# 46964                  0                    0                0
# 46965                  3                    2                1
#
#        team_points_last1_games_withcups  team_points_last3_games_withcups  \
# 46963                               1.0                          1.333333
# 46964                               3.0                          2.333333
# 46965                               3.0                          3.000000
#
#        team_points_last5_games_withcups  team_points_last10_games_withcups  \
# 46963                               1.4                                1.1
# 46964                               2.0                                1.5
# 46965                               2.0                                1.5
#
#        team_points_last20_games_withcups  \
# 46963                               1.10
# 46964                               2.00
# 46965                               1.65
#
#       team_goals_scored_last1_games_withcups  \
# 46963                                    0.0
# 46964                                    2.0
# 46965                                    2.0
#
#       team_goals_scored_last3_games_withcups  \
# 46963                               0.666667
# 46964                                    2.0
# 46965                               2.333333
#
#       team_goals_scored_last5_games_withcups  \
# 46963                                    0.8
# 46964                                    1.6
# 46965                                    1.6
#
#       team_goals_scored_last10_games_withcups  \
# 46963                                     0.9
# 46964                                     1.3
# 46965                                     1.1
#
#       team_goals_scored_last20_games_withcups  \
# 46963                                    0.85
# 46964                                     2.0
# 46965                                     1.5
#
#       team_goals_conceded_last1_games_withcups  \
# 46963                                      0.0
# 46964                                      1.0
# 46965                                      1.0
#
#       team_goals_conceded_last3_games_withcups  \
# 46963                                 1.333333
# 46964                                 0.666667
# 46965                                 0.666667
#
#       team_goals_conceded_last5_games_withcups  \
# 46963                                      1.0
# 46964                                      0.8
# 46965                                      0.8
#
#       team_goals_conceded_last10_games_withcups  \
# 46963                                       1.2
# 46964                                       1.1
# 46965                                       0.9
#
#       team_goals_conceded_last20_games_withcups  \
# 46963                                      1.25
# 46964                                      1.05
# 46965                                       0.9
#
#       team_goals_diff_last1_games_withcups  \
# 46963                                  0.0
# 46964                                  1.0
# 46965                                  1.0
#
#       team_goals_diff_last3_games_withcups  \
# 46963                            -0.666667
# 46964                             1.333333
# 46965                             1.666667
#
#       team_goals_diff_last5_games_withcups  \
# 46963                                 -0.2
# 46964                                  0.8
# 46965                                  0.8
#
#       team_goals_diff_last10_games_withcups  \
# 46963                                  -0.3
# 46964                                   0.2
# 46965                                   0.2
#
#       team_goals_diff_last20_games_withcups  team_points_last1_games_nopcups  \
# 46963                                  -0.4                              1.0
# 46964                                  0.95                              3.0
# 46965                                   0.6                              3.0
#
#        team_points_last3_games_nopcups  team_points_last5_games_nopcups  \
# 46963                         1.333333                              1.4
# 46964                         2.333333                              2.0
# 46965                         3.000000                              2.4
#
#        team_points_last10_games_nopcups  team_points_last20_games_nopcups  \
# 46963                               1.1                              1.10
# 46964                               1.9                              1.75
# 46965                               1.7                              1.65
#
#       team_goals_scored_last1_games_nopcups  \
# 46963                                   0.0
# 46964                                   2.0
# 46965                                   2.0
#
#       team_goals_scored_last3_games_nopcups  \
# 46963                              0.666667
# 46964                                   2.0
# 46965                              2.333333
#
#       team_goals_scored_last5_games_nopcups  \
# 46963                                   0.8
# 46964                                   1.6
# 46965                                   1.6
#
#       team_goals_scored_last10_games_nopcups  \
# 46963                                    0.9
# 46964                                    1.9
# 46965                                    1.4
#
#       team_goals_scored_last20_games_nopcups  \
# 46963                                   0.95
# 46964                                   1.85
# 46965                                    1.5
#
#       team_goals_conceded_last1_games_nopcups  \
# 46963                                     0.0
# 46964                                     1.0
# 46965                                     1.0
#
#       team_goals_conceded_last3_games_nopcups  \
# 46963                                1.333333
# 46964                                0.666667
# 46965                                0.666667
#
#       team_goals_conceded_last5_games_nopcups  \
# 46963                                     1.0
# 46964                                     1.0
# 46965                                     0.6
#
#       team_goals_conceded_last10_games_nopcups  \
# 46963                                      1.2
# 46964                                      1.3
# 46965                                      0.9
#
#       team_goals_conceded_last20_games_nopcups  \
# 46963                                      1.4
# 46964                                     1.25
# 46965                                      0.9
#
#       team_goals_diff_last1_games_nopcups team_goals_diff_last3_games_nopcups  \
# 46963                                 0.0                           -0.666667
# 46964                                 1.0                            1.333333
# 46965                                 1.0                            1.666667
#
#       team_goals_diff_last5_games_nopcups  \
# 46963                                -0.2
# 46964                                 0.6
# 46965                                 1.0
#
#       team_goals_diff_last10_games_nopcups  \
# 46963                                 -0.3
# 46964                                  0.6
# 46965                                  0.5
#
#       team_goals_diff_last20_games_nopcups
# 46963                                -0.45
# 46964                                  0.6
# 46965                                  0.6

# %% [markdown]
# Merge only home & away data with both home & away data

# %%
mask_form_nocups = mask_form_nocups.reset_index()

# %%
# Merge mask_form_nocups which contains already separated home & away data with mask_form_teams_nocups which has not yet be partitioned in home and away.
mask_form_nocups = mask_form_nocups.reset_index()
# By merging on home_id and date we create before columns for home (defined using home_ prefix)
mask_form_with_only_home_teams = pd.merge(mask_form_nocups, mask_form_teams_nocups.add_prefix('home_'), how='left', \
    left_on=['home_id', 'time_starting_at_date'], right_on=['home_team_id', 'home_time_starting_at_date']) # on home_id
# By merging on away_id and date we create before columns for away (defined using away_ prefix)
mask_form_complete = pd.merge(mask_form_with_only_home_teams, mask_form_teams_nocups.add_prefix('away_'), how='left', \
    left_on=['away_id', 'time_starting_at_date'], right_on=['away_team_id', 'away_time_starting_at_date']) # on_away
mask_form_complete = mask_form_complete[mask_form_complete['time_starting_at_date'] > '2016-06-06'].set_index('id')
mask_form_complete.head()
# Out:
#         index  home_id  away_id time_starting_at_date  league_is_cup  result  \
# id
# 251728   1826      430      591            2016-08-12              0       2
# 251738   1827     6789     2919            2016-08-12              0       0
# 2188     1828       22       42            2016-08-13              0       1
# 2208     1829       51       10            2016-08-13              0       2
# 2225     1830        7       26            2016-08-13              0       0
#
#         home_goals_scored  away_goals_scored  home_points  away_points  \
# id
# 251728                  0                  1            0            3
# 251738                  2                  2            1            1
# 2188                    2                  1            3            0
# 2208                    0                  1            0            3
# 2225                    1                  1            1            1
#
#         home_goals_conceded  away_goals_conceded  home_goals_diff  \
# id
# 251728                    1                    0               -1
# 251738                    2                    2                0
# 2188                      1                    2                1
# 2208                      1                    0               -1
# 2225                      1                    1                0
#
#         away_goals_diff  home_points_last1_games_withcups  \
# id
# 251728                1                               3.0
# 251738                0                               3.0
# 2188                 -1                               0.0
# 2208                  1                               3.0
# 2225                  0                               0.0
#
#         home_points_last3_games_withcups  home_points_last5_games_withcups  \
# id
# 251728                          2.000000                               1.4
# 251738                          3.000000                               2.4
# 2188                            1.500000                               1.5
# 2208                            2.333333                               2.0
# 2225                            0.000000                               0.0
#
#         home_points_last10_games_withcups  home_points_last20_games_withcups  \
# id
# 251728                                2.0                           1.842105
# 251738                                2.5                           2.100000
# 2188                                  1.5                           1.500000
# 2208                                  1.3                           1.350000
# 2225                                  0.0                           0.000000
#
#         away_points_last1_games_withcups  away_points_last3_games_withcups  \
# id
# 251728                               1.0                          1.333333
# 251738                               1.0                          1.333333
# 2188                                 1.0                          1.666667
# 2208                                 1.0                          0.666667
# 2225                                 0.0                          0.000000
#
#         away_points_last5_games_withcups  away_points_last10_games_withcups  \
# id
# 251728                               2.0                                2.2
# 251738                               1.4                                1.2
# 2188                                 2.2                                1.9
# 2208                                 0.6                                1.0
# 2225                                 0.8                                1.0
#
#         away_points_last20_games_withcups  \
# id
# 251728                               2.35
# 251738                               1.00
# 2188                                 2.00
# 2208                                 1.10
# 2225                                 1.25
#
#        home_goals_scored_last1_games_withcups  \
# id
# 251728                                    1.0
# 251738                                    3.0
# 2188                                      0.0
# 2208                                      2.0
# 2225                                      1.0
#
#        home_goals_scored_last3_games_withcups  \
# id
# 251728                                    1.0
# 251738                               2.666667
# 2188                                      0.5
# 2208                                 1.333333
# 2225                                      1.0
#
#        home_goals_scored_last5_games_withcups  \
# id
# 251728                                    0.8
# 251738                                    2.2
# 2188                                      0.5
# 2208                                      1.0
# 2225                                      1.0
#
#        home_goals_scored_last10_games_withcups  \
# id
# 251728                                     1.0
# 251738                                     2.3
# 2188                                       0.5
# 2208                                       1.0
# 2225                                       1.0
#
#        home_goals_scored_last20_games_withcups  \
# id
# 251728                                1.210526
# 251738                                    1.65
# 2188                                       0.5
# 2208                                      1.05
# 2225                                       1.0
#
#        away_goals_scored_last1_games_withcups  \
# id
# 251728                                    1.0
# 251738                                    0.0
# 2188                                      1.0
# 2208                                      1.0
# 2225                                      1.0
#
#        away_goals_scored_last3_games_withcups  \
# id
# 251728                               1.666667
# 251738                               1.666667
# 2188                                 1.333333
# 2208                                 0.666667
# 2225                                 0.666667
#
#        away_goals_scored_last5_games_withcups  \
# id
# 251728                                    3.2
# 251738                                    1.4
# 2188                                      1.2
# 2208                                      0.6
# 2225                                      1.0
#
#        away_goals_scored_last10_games_withcups  \
# id
# 251728                                     2.4
# 251738                                     1.3
# 2188                                       1.4
# 2208                                       0.8
# 2225                                       1.0
#
#        away_goals_scored_last20_games_withcups  \
# id
# 251728                                    2.35
# 251738                                0.842105
# 2188                                      1.75
# 2208                                       0.8
# 2225                                      0.95
#
#        home_goals_conceded_last1_games_withcups  \
# id
# 251728                                      0.0
# 251738                                      1.0
# 2188                                        4.0
# 2208                                        1.0
# 2225                                        2.0
#
#        home_goals_conceded_last3_games_withcups  \
# id
# 251728                                 0.666667
# 251738                                      1.0
# 2188                                        2.0
# 2208                                   0.666667
# 2225                                        2.0
#
#        home_goals_conceded_last5_games_withcups  \
# id
# 251728                                      0.8
# 251738                                      1.2
# 2188                                        2.0
# 2208                                        0.6
# 2225                                        2.0
#
#        home_goals_conceded_last10_games_withcups  \
# id
# 251728                                       0.4
# 251738                                       0.9
# 2188                                         2.0
# 2208                                         1.2
# 2225                                         2.0
#
#        home_goals_conceded_last20_games_withcups  \
# id
# 251728                                  0.736842
# 251738                                      0.85
# 2188                                         2.0
# 2208                                         1.1
# 2225                                         2.0
#
#        away_goals_conceded_last1_games_withcups  \
# id
# 251728                                      1.0
# 251738                                      0.0
# 2188                                        1.0
# 2208                                        1.0
# 2225                                        2.0
#
#        away_goals_conceded_last3_games_withcups  \
# id
# 251728                                 0.666667
# 251738                                      1.0
# 2188                                   0.666667
# 2208                                   1.333333
# 2225                                   3.333333
#
#        away_goals_conceded_last5_games_withcups  \
# id
# 251728                                      0.4
# 251738                                      1.6
# 2188                                        0.4
# 2208                                        1.2
# 2225                                        2.4
#
#        away_goals_conceded_last10_games_withcups  \
# id
# 251728                                       0.6
# 251738                                       1.5
# 2188                                         0.8
# 2208                                         1.2
# 2225                                         2.1
#
#        away_goals_conceded_last20_games_withcups  \
# id
# 251728                                      0.45
# 251738                                  1.473684
# 2188                                         1.0
# 2208                                        1.25
# 2225                                        1.55
#
#        home_goals_diff_last1_games_withcups  \
# id
# 251728                                  1.0
# 251738                                  2.0
# 2188                                   -4.0
# 2208                                    1.0
# 2225                                   -1.0
#
#        home_goals_diff_last3_games_withcups  \
# id
# 251728                             0.333333
# 251738                             1.666667
# 2188                                   -1.5
# 2208                               0.666667
# 2225                                   -1.0
#
#        home_goals_diff_last5_games_withcups  \
# id
# 251728                                  0.0
# 251738                                  1.0
# 2188                                   -1.5
# 2208                                    0.4
# 2225                                   -1.0
#
#        home_goals_diff_last10_games_withcups  \
# id
# 251728                                   0.6
# 251738                                   1.4
# 2188                                    -1.5
# 2208                                    -0.2
# 2225                                    -1.0
#
#        home_goals_diff_last20_games_withcups  \
# id
# 251728                              0.473684
# 251738                                   0.8
# 2188                                    -1.5
# 2208                                   -0.05
# 2225                                    -1.0
#
#        away_goals_diff_last1_games_withcups  \
# id
# 251728                                  0.0
# 251738                                  0.0
# 2188                                    0.0
# 2208                                    0.0
# 2225                                   -1.0
#
#        away_goals_diff_last3_games_withcups  \
# id
# 251728                                  1.0
# 251738                             0.666667
# 2188                               0.666667
# 2208                              -0.666667
# 2225                              -2.666667
#
#        away_goals_diff_last5_games_withcups  \
# id
# 251728                                  2.8
# 251738                                 -0.2
# 2188                                    0.8
# 2208                                   -0.6
# 2225                                   -1.4
#
#        away_goals_diff_last10_games_withcups  \
# id
# 251728                                   1.8
# 251738                                  -0.2
# 2188                                     0.6
# 2208                                    -0.4
# 2225                                    -1.1
#
#        away_goals_diff_last20_games_withcups  home_points_last1_games_nopcups  \
# id
# 251728                                   1.9                              3.0
# 251738                             -0.631579                              3.0
# 2188                                    0.75                              NaN
# 2208                                   -0.45                              3.0
# 2225                                    -0.6                              NaN
#
#         home_points_last3_games_nopcups  home_points_last5_games_nopcups  \
# id
# 251728                         2.000000                              1.4
# 251738                         3.000000                              2.0
# 2188                                NaN                              NaN
# 2208                           2.333333                              1.4
# 2225                                NaN                              NaN
#
#         home_points_last10_games_nopcups  home_points_last20_games_nopcups  \
# id
# 251728                               2.0                          1.842105
# 251738                               2.3                          1.894737
# 2188                                 NaN                               NaN
# 2208                                 0.8                          1.105263
# 2225                                 NaN                               NaN
#
#         away_points_last1_games_nopcups  away_points_last3_games_nopcups  \
# id
# 251728                              1.0                         2.333333
# 251738                              1.0                         1.333333
# 2188                                1.0                         1.666667
# 2208                                1.0                         0.666667
# 2225                                0.0                         0.000000
#
#         away_points_last5_games_nopcups  away_points_last10_games_nopcups  \
# id
# 251728                              2.0                               2.5
# 251738                              1.4                               1.2
# 2188                                2.2                               1.8
# 2208                                0.6                               0.8
# 2225                                0.8                               1.0
#
#         away_points_last20_games_nopcups  \
# id
# 251728                          2.526316
# 251738                          1.000000
# 2188                            2.052632
# 2208                            1.052632
# 2225                            1.210526
#
#        home_goals_scored_last1_games_nopcups  \
# id
# 251728                                   1.0
# 251738                                   2.0
# 2188                                    <NA>
# 2208                                     2.0
# 2225                                    <NA>
#
#        home_goals_scored_last3_games_nopcups  \
# id
# 251728                                   1.0
# 251738                              2.333333
# 2188                                    <NA>
# 2208                                     1.0
# 2225                                    <NA>
#
#        home_goals_scored_last5_games_nopcups  \
# id
# 251728                                   0.8
# 251738                                   2.0
# 2188                                    <NA>
# 2208                                     0.8
# 2225                                    <NA>
#
#        home_goals_scored_last10_games_nopcups  \
# id
# 251728                                    1.0
# 251738                                    2.2
# 2188                                     <NA>
# 2208                                      0.7
# 2225                                     <NA>
#
#        home_goals_scored_last20_games_nopcups  \
# id
# 251728                               1.210526
# 251738                               1.578947
# 2188                                     <NA>
# 2208                                      1.0
# 2225                                     <NA>
#
#        away_goals_scored_last1_games_nopcups  \
# id
# 251728                                   1.0
# 251738                                   0.0
# 2188                                     1.0
# 2208                                     1.0
# 2225                                     1.0
#
#        away_goals_scored_last3_games_nopcups  \
# id
# 251728                              2.333333
# 251738                              1.666667
# 2188                                1.333333
# 2208                                0.666667
# 2225                                0.666667
#
#        away_goals_scored_last5_games_nopcups  \
# id
# 251728                                   3.4
# 251738                                   1.4
# 2188                                     1.2
# 2208                                     0.6
# 2225                                     1.0
#
#        away_goals_scored_last10_games_nopcups  \
# id
# 251728                                    2.8
# 251738                                    1.3
# 2188                                      1.2
# 2208                                      0.8
# 2225                                      1.3
#
#        away_goals_scored_last20_games_nopcups  \
# id
# 251728                               2.263158
# 251738                               0.842105
# 2188                                 1.736842
# 2208                                 0.736842
# 2225                                      1.0
#
#        home_goals_conceded_last1_games_nopcups  \
# id
# 251728                                     0.0
# 251738                                     0.0
# 2188                                      <NA>
# 2208                                       1.0
# 2225                                      <NA>
#
#        home_goals_conceded_last3_games_nopcups  \
# id
# 251728                                0.666667
# 251738                                     1.0
# 2188                                      <NA>
# 2208                                  0.333333
# 2225                                      <NA>
#
#        home_goals_conceded_last5_games_nopcups  \
# id
# 251728                                     0.8
# 251738                                     1.4
# 2188                                      <NA>
# 2208                                       0.8
# 2225                                      <NA>
#
#        home_goals_conceded_last10_games_nopcups  \
# id
# 251728                                      0.4
# 251738                                      1.0
# 2188                                       <NA>
# 2208                                        1.4
# 2225                                       <NA>
#
#        home_goals_conceded_last20_games_nopcups  \
# id
# 251728                                 0.736842
# 251738                                      1.0
# 2188                                       <NA>
# 2208                                   1.210526
# 2225                                       <NA>
#
#        away_goals_conceded_last1_games_nopcups  \
# id
# 251728                                     1.0
# 251738                                     0.0
# 2188                                       1.0
# 2208                                       1.0
# 2225                                       2.0
#
#        away_goals_conceded_last3_games_nopcups  \
# id
# 251728                                0.333333
# 251738                                     1.0
# 2188                                  0.666667
# 2208                                  1.333333
# 2225                                  3.333333
#
#        away_goals_conceded_last5_games_nopcups  \
# id
# 251728                                     0.6
# 251738                                     1.6
# 2188                                       0.4
# 2208                                       1.2
# 2225                                       2.4
#
#        away_goals_conceded_last10_games_nopcups  \
# id
# 251728                                      0.4
# 251738                                      1.5
# 2188                                        0.7
# 2208                                        1.4
# 2225                                        2.4
#
#        away_goals_conceded_last20_games_nopcups  \
# id
# 251728                                 0.368421
# 251738                                 1.473684
# 2188                                   0.947368
# 2208                                   1.157895
# 2225                                   1.631579
#
#        home_goals_diff_last1_games_nopcups  \
# id
# 251728                                 1.0
# 251738                                 2.0
# 2188                                  <NA>
# 2208                                   1.0
# 2225                                  <NA>
#
#        home_goals_diff_last3_games_nopcups  \
# id
# 251728                            0.333333
# 251738                            1.333333
# 2188                                  <NA>
# 2208                              0.666667
# 2225                                  <NA>
#
#        home_goals_diff_last5_games_nopcups  \
# id
# 251728                                 0.0
# 251738                                 0.6
# 2188                                  <NA>
# 2208                                   0.0
# 2225                                  <NA>
#
#        home_goals_diff_last10_games_nopcups  \
# id
# 251728                                  0.6
# 251738                                  1.2
# 2188                                   <NA>
# 2208                                   -0.7
# 2225                                   <NA>
#
#        home_goals_diff_last20_games_nopcups  \
# id
# 251728                             0.473684
# 251738                             0.578947
# 2188                                   <NA>
# 2208                              -0.210526
# 2225                                   <NA>
#
#        away_goals_diff_last1_games_nopcups  \
# id
# 251728                                 0.0
# 251738                                 0.0
# 2188                                   0.0
# 2208                                   0.0
# 2225                                  -1.0
#
#        away_goals_diff_last3_games_nopcups  \
# id
# 251728                                 2.0
# 251738                            0.666667
# 2188                              0.666667
# 2208                             -0.666667
# 2225                             -2.666667
#
#        away_goals_diff_last5_games_nopcups  \
# id
# 251728                                 2.8
# 251738                                -0.2
# 2188                                   0.8
# 2208                                  -0.6
# 2225                                  -1.4
#
#        away_goals_diff_last10_games_nopcups  \
# id
# 251728                                  2.4
# 251738                                 -0.2
# 2188                                    0.5
# 2208                                   -0.6
# 2225                                   -1.1
#
#        away_goals_diff_last20_games_nopcups  home_team_id  \
# id
# 251728                             1.894737           430
# 251738                            -0.631579          6789
# 2188                               0.789474            22
# 2208                              -0.421053            51
# 2225                              -0.631579             7
#
#        home_time_starting_at_date  home_league_is_cup  home_team_points  \
# id
# 251728                 2016-08-12                   0                 0
# 251738                 2016-08-12                   0                 1
# 2188                   2016-08-13                   0                 3
# 2208                   2016-08-13                   0                 0
# 2225                   2016-08-13                   0                 1
#
#         home_team_goals_scored  home_team_goals_conceded  \
# id
# 251728                       0                         1
# 251738                       2                         2
# 2188                         2                         1
# 2208                         0                         1
# 2225                         1                         1
#
#         home_team_goals_diff  home_team_points_last1_games_withcups  \
# id
# 251728                    -1                                    3.0
# 251738                     0                                    3.0
# 2188                       1                                    0.0
# 2208                      -1                                    0.0
# 2225                       0                                    0.0
#
#         home_team_points_last3_games_withcups  \
# id
# 251728                               2.333333
# 251738                               2.000000
# 2188                                 1.333333
# 2208                                 1.000000
# 2225                                 0.000000
#
#         home_team_points_last5_games_withcups  \
# id
# 251728                                   1.40
# 251738                                   1.80
# 2188                                     1.75
# 2208                                     1.20
# 2225                                     0.00
#
#         home_team_points_last10_games_withcups  \
# id
# 251728                                    1.20
# 251738                                    1.60
# 2188                                      1.75
# 2208                                      1.20
# 2225                                      0.00
#
#         home_team_points_last20_games_withcups  \
# id
# 251728                                    1.55
# 251738                                    1.75
# 2188                                      1.75
# 2208                                      1.15
# 2225                                      0.00
#
#        home_team_goals_scored_last1_games_withcups  \
# id
# 251728                                         2.0
# 251738                                         3.0
# 2188                                           0.0
# 2208                                           1.0
# 2225                                           1.0
#
#        home_team_goals_scored_last3_games_withcups  \
# id
# 251728                                         1.0
# 251738                                         2.0
# 2188                                           1.0
# 2208                                           1.0
# 2225                                           1.0
#
#        home_team_goals_scored_last5_games_withcups  \
# id
# 251728                                         1.0
# 251738                                         2.0
# 2188                                           1.0
# 2208                                           1.0
# 2225                                           1.0
#
#        home_team_goals_scored_last10_games_withcups  \
# id
# 251728                                          0.9
# 251738                                          1.7
# 2188                                            1.0
# 2208                                            0.9
# 2225                                            1.0
#
#        home_team_goals_scored_last20_games_withcups  \
# id
# 251728                                          0.9
# 251738                                          1.7
# 2188                                            1.0
# 2208                                            1.1
# 2225                                            1.0
#
#        home_team_goals_conceded_last1_games_withcups  \
# id
# 251728                                           1.0
# 251738                                           1.0
# 2188                                             4.0
# 2208                                             4.0
# 2225                                             2.0
#
#        home_team_goals_conceded_last3_games_withcups  \
# id
# 251728                                      0.333333
# 251738                                           1.0
# 2188                                        1.666667
# 2208                                             2.0
# 2225                                             2.0
#
#        home_team_goals_conceded_last5_games_withcups  \
# id
# 251728                                           1.0
# 251738                                           2.2
# 2188                                            1.25
# 2208                                             1.8
# 2225                                             2.0
#
#        home_team_goals_conceded_last10_games_withcups  \
# id
# 251728                                            1.3
# 251738                                            1.9
# 2188                                             1.25
# 2208                                              1.3
# 2225                                              2.0
#
#        home_team_goals_conceded_last20_games_withcups  \
# id
# 251728                                            0.9
# 251738                                            1.4
# 2188                                             1.25
# 2208                                              1.4
# 2225                                              2.0
#
#        home_team_goals_diff_last1_games_withcups  \
# id
# 251728                                       1.0
# 251738                                       2.0
# 2188                                        -4.0
# 2208                                        -3.0
# 2225                                        -1.0
#
#        home_team_goals_diff_last3_games_withcups  \
# id
# 251728                                  0.666667
# 251738                                       1.0
# 2188                                   -0.666667
# 2208                                        -1.0
# 2225                                        -1.0
#
#        home_team_goals_diff_last5_games_withcups  \
# id
# 251728                                       0.0
# 251738                                      -0.2
# 2188                                       -0.25
# 2208                                        -0.8
# 2225                                        -1.0
#
#        home_team_goals_diff_last10_games_withcups  \
# id
# 251728                                       -0.4
# 251738                                       -0.2
# 2188                                        -0.25
# 2208                                         -0.4
# 2225                                         -1.0
#
#        home_team_goals_diff_last20_games_withcups  \
# id
# 251728                                        0.0
# 251738                                        0.3
# 2188                                        -0.25
# 2208                                         -0.3
# 2225                                         -1.0
#
#         home_team_points_last1_games_nopcups  \
# id
# 251728                                   3.0
# 251738                                   3.0
# 2188                                     NaN
# 2208                                     0.0
# 2225                                     NaN
#
#         home_team_points_last3_games_nopcups  \
# id
# 251728                              2.333333
# 251738                              2.000000
# 2188                                     NaN
# 2208                                1.000000
# 2225                                     NaN
#
#         home_team_points_last5_games_nopcups  \
# id
# 251728                                   1.4
# 251738                                   2.0
# 2188                                     NaN
# 2208                                     0.8
# 2225                                     NaN
#
#         home_team_points_last10_games_nopcups  \
# id
# 251728                                    1.2
# 251738                                    1.5
# 2188                                      NaN
# 2208                                      0.9
# 2225                                      NaN
#
#         home_team_points_last20_games_nopcups  \
# id
# 251728                                   1.55
# 251738                                   1.70
# 2188                                      NaN
# 2208                                     0.60
# 2225                                      NaN
#
#        home_team_goals_scored_last1_games_nopcups  \
# id
# 251728                                        2.0
# 251738                                        2.0
# 2188                                         <NA>
# 2208                                          1.0
# 2225                                         <NA>
#
#        home_team_goals_scored_last3_games_nopcups  \
# id
# 251728                                        1.0
# 251738                                        2.0
# 2188                                         <NA>
# 2208                                          1.0
# 2225                                         <NA>
#
#        home_team_goals_scored_last5_games_nopcups  \
# id
# 251728                                        1.0
# 251738                                        1.8
# 2188                                         <NA>
# 2208                                          0.8
# 2225                                         <NA>
#
#        home_team_goals_scored_last10_games_nopcups  \
# id
# 251728                                         0.9
# 251738                                         1.7
# 2188                                          <NA>
# 2208                                           0.8
# 2225                                          <NA>
#
#        home_team_goals_scored_last20_games_nopcups  \
# id
# 251728                                         0.9
# 251738                                         1.6
# 2188                                          <NA>
# 2208                                           0.8
# 2225                                          <NA>
#
#        home_team_goals_conceded_last1_games_nopcups  \
# id
# 251728                                          1.0
# 251738                                          0.0
# 2188                                           <NA>
# 2208                                            4.0
# 2225                                           <NA>
#
#        home_team_goals_conceded_last3_games_nopcups  \
# id
# 251728                                     0.333333
# 251738                                     2.666667
# 2188                                           <NA>
# 2208                                            2.0
# 2225                                           <NA>
#
#        home_team_goals_conceded_last5_games_nopcups  \
# id
# 251728                                          1.0
# 251738                                          2.0
# 2188                                           <NA>
# 2208                                            1.8
# 2225                                           <NA>
#
#        home_team_goals_conceded_last10_games_nopcups  \
# id
# 251728                                           1.3
# 251738                                           2.0
# 2188                                            <NA>
# 2208                                             1.4
# 2225                                            <NA>
#
#        home_team_goals_conceded_last20_games_nopcups  \
# id
# 251728                                           0.9
# 251738                                          1.35
# 2188                                            <NA>
# 2208                                            1.75
# 2225                                            <NA>
#
#        home_team_goals_diff_last1_games_nopcups  \
# id
# 251728                                      1.0
# 251738                                      2.0
# 2188                                       <NA>
# 2208                                       -3.0
# 2225                                       <NA>
#
#        home_team_goals_diff_last3_games_nopcups  \
# id
# 251728                                 0.666667
# 251738                                -0.666667
# 2188                                       <NA>
# 2208                                       -1.0
# 2225                                       <NA>
#
#        home_team_goals_diff_last5_games_nopcups  \
# id
# 251728                                      0.0
# 251738                                     -0.2
# 2188                                       <NA>
# 2208                                       -1.0
# 2225                                       <NA>
#
#        home_team_goals_diff_last10_games_nopcups  \
# id
# 251728                                      -0.4
# 251738                                      -0.3
# 2188                                        <NA>
# 2208                                        -0.6
# 2225                                        <NA>
#
#        home_team_goals_diff_last20_games_nopcups  away_team_id  \
# id
# 251728                                       0.0           591
# 251738                                      0.25          2919
# 2188                                        <NA>            42
# 2208                                       -0.95            10
# 2225                                        <NA>            26
#
#        away_time_starting_at_date  away_league_is_cup  away_team_points  \
# id
# 251728                 2016-08-12                   0                 3
# 251738                 2016-08-12                   0                 1
# 2188                   2016-08-13                   0                 0
# 2208                   2016-08-13                   0                 3
# 2225                   2016-08-13                   0                 1
#
#         away_team_goals_scored  away_team_goals_conceded  \
# id
# 251728                       1                         0
# 251738                       2                         2
# 2188                         1                         2
# 2208                         1                         0
# 2225                         1                         1
#
#         away_team_goals_diff  away_team_points_last1_games_withcups  \
# id
# 251728                     1                                    3.0
# 251738                     0                                    0.0
# 2188                      -1                                    1.0
# 2208                       1                                    1.0
# 2225                       0                                    3.0
#
#         away_team_points_last3_games_withcups  \
# id
# 251728                               2.333333
# 251738                               0.333333
# 2188                                 1.666667
# 2208                                 0.666667
# 2225                                 1.333333
#
#         away_team_points_last5_games_withcups  \
# id
# 251728                                    2.6
# 251738                                    1.0
# 2188                                      1.8
# 2208                                      0.6
# 2225                                      0.8
#
#         away_team_points_last10_games_withcups  \
# id
# 251728                                     2.0
# 251738                                     1.2
# 2188                                       2.4
# 2208                                       0.7
# 2225                                       0.9
#
#         away_team_points_last20_games_withcups  \
# id
# 251728                                    2.15
# 251738                                    1.25
# 2188                                      2.10
# 2208                                      1.00
# 2225                                      1.25
#
#        away_team_goals_scored_last1_games_withcups  \
# id
# 251728                                         4.0
# 251738                                         2.0
# 2188                                           1.0
# 2208                                           1.0
# 2225                                           2.0
#
#        away_team_goals_scored_last3_games_withcups  \
# id
# 251728                                         3.0
# 251738                                    1.333333
# 2188                                      1.666667
# 2208                                      0.666667
# 2225                                      1.333333
#
#        away_team_goals_scored_last5_games_withcups  \
# id
# 251728                                         3.8
# 251738                                         1.6
# 2188                                           2.2
# 2208                                           0.6
# 2225                                           0.8
#
#        away_team_goals_scored_last10_games_withcups  \
# id
# 251728                                          2.7
# 251738                                          1.4
# 2188                                            1.7
# 2208                                            0.5
# 2225                                            1.1
#
#        away_team_goals_scored_last20_games_withcups  \
# id
# 251728                                          2.6
# 251738                                          1.5
# 2188                                           1.65
# 2208                                            0.8
# 2225                                            1.1
#
#        away_team_goals_conceded_last1_games_withcups  \
# id
# 251728                                           0.0
# 251738                                           3.0
# 2188                                             1.0
# 2208                                             1.0
# 2225                                             1.0
#
#        away_team_goals_conceded_last3_games_withcups  \
# id
# 251728                                      0.333333
# 251738                                           2.0
# 2188                                             1.0
# 2208                                        1.666667
# 2225                                        1.333333
#
#        away_team_goals_conceded_last5_games_withcups  \
# id
# 251728                                           0.2
# 251738                                           1.4
# 2188                                             1.0
# 2208                                             1.6
# 2225                                             2.4
#
#        away_team_goals_conceded_last10_games_withcups  \
# id
# 251728                                            0.7
# 251738                                            1.6
# 2188                                              0.5
# 2208                                              1.2
# 2225                                              2.2
#
#        away_team_goals_conceded_last20_games_withcups  \
# id
# 251728                                            0.7
# 251738                                           1.55
# 2188                                             0.75
# 2208                                              1.3
# 2225                                              1.8
#
#        away_team_goals_diff_last1_games_withcups  \
# id
# 251728                                       4.0
# 251738                                      -1.0
# 2188                                         0.0
# 2208                                         0.0
# 2225                                         1.0
#
#        away_team_goals_diff_last3_games_withcups  \
# id
# 251728                                  2.666667
# 251738                                 -0.666667
# 2188                                    0.666667
# 2208                                        -1.0
# 2225                                         0.0
#
#        away_team_goals_diff_last5_games_withcups  \
# id
# 251728                                       3.6
# 251738                                       0.2
# 2188                                         1.2
# 2208                                        -1.0
# 2225                                        -1.6
#
#        away_team_goals_diff_last10_games_withcups  \
# id
# 251728                                        2.0
# 251738                                       -0.2
# 2188                                          1.2
# 2208                                         -0.7
# 2225                                         -1.1
#
#        away_team_goals_diff_last20_games_withcups  \
# id
# 251728                                        1.9
# 251738                                      -0.05
# 2188                                          0.9
# 2208                                         -0.5
# 2225                                         -0.7
#
#         away_team_points_last1_games_nopcups  \
# id
# 251728                                   3.0
# 251738                                   0.0
# 2188                                     1.0
# 2208                                     1.0
# 2225                                     3.0
#
#         away_team_points_last3_games_nopcups  \
# id
# 251728                              2.333333
# 251738                              0.333333
# 2188                                1.666667
# 2208                                0.666667
# 2225                                1.333333
#
#         away_team_points_last5_games_nopcups  \
# id
# 251728                                   2.6
# 251738                                   1.0
# 2188                                     1.8
# 2208                                     0.6
# 2225                                     0.8
#
#         away_team_points_last10_games_nopcups  \
# id
# 251728                                    2.3
# 251738                                    1.2
# 2188                                      2.4
# 2208                                      0.7
# 2225                                      0.9
#
#         away_team_points_last20_games_nopcups  \
# id
# 251728                                   2.40
# 251738                                   1.25
# 2188                                     2.15
# 2208                                     1.15
# 2225                                     1.25
#
#        away_team_goals_scored_last1_games_nopcups  \
# id
# 251728                                        4.0
# 251738                                        2.0
# 2188                                          1.0
# 2208                                          1.0
# 2225                                          2.0
#
#        away_team_goals_scored_last3_games_nopcups  \
# id
# 251728                                        3.0
# 251738                                   1.333333
# 2188                                     1.666667
# 2208                                     0.666667
# 2225                                     1.333333
#
#        away_team_goals_scored_last5_games_nopcups  \
# id
# 251728                                        3.8
# 251738                                        1.6
# 2188                                          2.2
# 2208                                          0.6
# 2225                                          0.8
#
#        away_team_goals_scored_last10_games_nopcups  \
# id
# 251728                                         3.4
# 251738                                         1.4
# 2188                                           1.7
# 2208                                           0.5
# 2225                                           1.1
#
#        away_team_goals_scored_last20_games_nopcups  \
# id
# 251728                                        2.85
# 251738                                         1.5
# 2188                                          1.55
# 2208                                          0.85
# 2225                                          1.25
#
#        away_team_goals_conceded_last1_games_nopcups  \
# id
# 251728                                          0.0
# 251738                                          3.0
# 2188                                            1.0
# 2208                                            1.0
# 2225                                            1.0
#
#        away_team_goals_conceded_last3_games_nopcups  \
# id
# 251728                                     0.333333
# 251738                                          2.0
# 2188                                            1.0
# 2208                                       1.666667
# 2225                                       1.333333
#
#        away_team_goals_conceded_last5_games_nopcups  \
# id
# 251728                                          0.2
# 251738                                          1.4
# 2188                                            1.0
# 2208                                            1.6
# 2225                                            2.4
#
#        away_team_goals_conceded_last10_games_nopcups  \
# id
# 251728                                           0.4
# 251738                                           1.6
# 2188                                             0.5
# 2208                                             1.2
# 2225                                             2.2
#
#        away_team_goals_conceded_last20_games_nopcups  \
# id
# 251728                                           0.5
# 251738                                          1.55
# 2188                                            0.55
# 2208                                             1.2
# 2225                                            1.95
#
#        away_team_goals_diff_last1_games_nopcups  \
# id
# 251728                                      4.0
# 251738                                     -1.0
# 2188                                        0.0
# 2208                                        0.0
# 2225                                        1.0
#
#        away_team_goals_diff_last3_games_nopcups  \
# id
# 251728                                 2.666667
# 251738                                -0.666667
# 2188                                   0.666667
# 2208                                       -1.0
# 2225                                        0.0
#
#        away_team_goals_diff_last5_games_nopcups  \
# id
# 251728                                      3.6
# 251738                                      0.2
# 2188                                        1.2
# 2208                                       -1.0
# 2225                                       -1.6
#
#        away_team_goals_diff_last10_games_nopcups  \
# id
# 251728                                       3.0
# 251738                                      -0.2
# 2188                                         1.2
# 2208                                        -0.7
# 2225                                        -1.1
#
#        away_team_goals_diff_last20_games_nopcups
# id
# 251728                                      2.35
# 251738                                     -0.05
# 2188                                         1.0
# 2208                                       -0.35
# 2225                                        -0.7

# %%
mask_form_complete.to_csv('../../Data/Modeling_Before_Preparation/Form_data_v01.csv')

# %% [markdown]
# ## *Stats Data*

# %%
def avg_value_nan_closest_dates(df, date_col, value_col, n_size):
    """Given a DataFrame, a column and a integer n; this function returns the average for the specified column in the DataFrame of the last (considering precedent and closest dates) n_size number of values.

    df: DataFrame
    date_col: column in df which contains dates values
    value_col: column of values to average from
    n_size: number of last values (in date) 
    """
    with warnings.catch_warnings():
        warnings.filterwarnings('error')
        try:
            x = np.mean(df.loc[df[date_col].nlargest(n=n_size, keep='last').index, value_col])
        except RuntimeWarning:
            x=np.NaN  
    return x
    
def avg_nan_new_features(df, list_features, list_n_games, suffix_new_columns=''):
    """This function adds new columns to the provided DataFrame, containing the features in list_features averaged on the last n past observation contained in list_n_games.
    
    df: DataFrame
    list_features: list of features for new form features
    list_n_games: list for numbers of last matches to consider from
    """
    for elem in tqdm(list(product(list_features, list_n_games))):
        # tqdm.pandas(desc=(elem[0] + ' over the last ' + str(elem[1]) + ' games')) --> progress_apply()
        team_id = 'home_id' if 'home' in elem[0] else 'away_id' if 'away' in elem[0] else 'team_id' if 'team' in elem[0] else Exception(ValueError)
        # Apply avg_value_n_closest_dates by row
        df.loc[:, elem[0] + '_last' + str(elem[1]) + '_games' + suffix_new_columns] = df.apply(lambda x: avg_value_nan_closest_dates(\
                df = df.loc[((x[team_id] == df[team_id]) & (x['time_starting_at_date'] > df['time_starting_at_date'])), :], date_col = 'time_starting_at_date', value_col = elem[0], n_size=elem[1]), axis=1)
                
    return df

# %%
# Select general columns & stats columns 
cols = ['home_id','away_id','time_starting_at_date','league_is_cup'] + \
    static.loc[:,'home_shots_total':'away_attacks_dangerous_attacks'].columns.tolist()
# Filter for desired columns and only non-cup observations 
mask_stats = static.loc[static['league_is_cup'] == 0, cols]
# Create both home & away differentials columns for all types (home is home - away, while away is away - home)
col_names_for_differentials = ['shots_total','shots_ongoal','shots_offgoal','shots_blocked','shots_insidebox','shots_outsidebox','fouls','corners','offsides','possessiontime','yellowcards','redcards','yellowredcards','saves','tackles','passes_total','passes_accurate','passes_percentage','attacks_attacks','attacks_dangerous_attacks']
for col_type in col_names_for_differentials:
    mask_stats.loc[:, 'home_' + 'diff_' + col_type] = mask_stats.loc[:, 'home_' + col_type] - mask_stats.loc[:, 'away_' + col_type]
    mask_stats.loc[:, 'away_' + 'diff_' + col_type] = mask_stats.loc[:, 'away_' + col_type] - mask_stats.loc[:, 'home_' + col_type]
# Downcast numeric columns (integers)
mask_stats[mask_stats.select_dtypes(int).columns] = mask_stats.select_dtypes(int).apply(pd.to_numeric, errors='coerce', downcast='integer')
# Print some info
print(mask_stats.shape)
mask_stats.head(2)
# Out:
# (12362, 84)
#         home_id  away_id time_starting_at_date  league_is_cup  \
# id
# 251711      690      591            2015-08-07              0
# 849          14        6            2015-08-08              0
#
#         home_shots_total  home_shots_ongoal  home_shots_offgoal  \
# id
# 251711                12                  2                   0
# 849                    9                  1                   0
#
#         home_shots_blocked  home_shots_insidebox  home_shots_outsidebox  \
# id
# 251711                   0                     0                      0
# 849                      0                     0                      0
#
#         home_fouls  home_corners  home_offsides  home_possessiontime  \
# id
# 251711          20             3              0                   52
# 849             12             1              1                   50
#
#         home_yellowcards  home_redcards  home_yellowredcards  home_saves  \
# id
# 251711                 3              0                    0           1
# 849                    2              0                    0           4
#
#         home_tackles  away_shots_total  away_shots_ongoal  away_shots_offgoal  \
# id
# 251711            16                 7                  2                   0
# 849               17                 9                  4                   0
#
#         away_shots_blocked  away_shots_insidebox  away_shots_outsidebox  \
# id
# 251711                   0                     0                      0
# 849                      0                     0                      0
#
#         away_fouls  away_corners  away_offsides  away_possessiontime  \
# id
# 251711          17             2              2                   48
# 849             12             2              2                   50
#
#         away_yellowcards  away_redcards  away_yellowredcards  away_saves  \
# id
# 251711                 2              1                    0           2
# 849                    3              0                    0           1
#
#         away_tackles  home_passes_total  home_passes_accurate  \
# id
# 251711            17               <NA>                  <NA>
# 849               17               <NA>                  <NA>
#
#         home_passes_percentage  away_passes_total  away_passes_accurate  \
# id
# 251711                     NaN               <NA>                  <NA>
# 849                        NaN               <NA>                  <NA>
#
#         away_passes_percentage  home_attacks_attacks  \
# id
# 251711                     NaN                   106
# 849                        NaN                   100
#
#         home_attacks_dangerous_attacks  away_attacks_attacks  \
# id
# 251711                              48                    93
# 849                                 45                    96
#
#         away_attacks_dangerous_attacks  home_diff_shots_total  \
# id
# 251711                              42                      5
# 849                                 48                      0
#
#         away_diff_shots_total  home_diff_shots_ongoal  away_diff_shots_ongoal  \
# id
# 251711                     -5                       0                       0
# 849                         0                      -3                       3
#
#         home_diff_shots_offgoal  away_diff_shots_offgoal  \
# id
# 251711                        0                        0
# 849                           0                        0
#
#         home_diff_shots_blocked  away_diff_shots_blocked  \
# id
# 251711                        0                        0
# 849                           0                        0
#
#         home_diff_shots_insidebox  away_diff_shots_insidebox  \
# id
# 251711                          0                          0
# 849                             0                          0
#
#         home_diff_shots_outsidebox  away_diff_shots_outsidebox  \
# id
# 251711                           0                           0
# 849                              0                           0
#
#         home_diff_fouls  away_diff_fouls  home_diff_corners  \
# id
# 251711                3               -3                  1
# 849                   0                0                 -1
#
#         away_diff_corners  home_diff_offsides  away_diff_offsides  \
# id
# 251711                 -1                  -2                   2
# 849                     1                  -1                   1
#
#         home_diff_possessiontime  away_diff_possessiontime  \
# id
# 251711                         4                        -4
# 849                            0                         0
#
#         home_diff_yellowcards  away_diff_yellowcards  home_diff_redcards  \
# id
# 251711                      1                     -1                  -1
# 849                        -1                      1                   0
#
#         away_diff_redcards  home_diff_yellowredcards  \
# id
# 251711                   1                         0
# 849                      0                         0
#
#         away_diff_yellowredcards  home_diff_saves  away_diff_saves  \
# id
# 251711                         0               -1                1
# 849                            0                3               -3
#
#         home_diff_tackles  away_diff_tackles  home_diff_passes_total  \
# id
# 251711                 -1                  1                    <NA>
# 849                     0                  0                    <NA>
#
#         away_diff_passes_total  home_diff_passes_accurate  \
# id
# 251711                    <NA>                       <NA>
# 849                       <NA>                       <NA>
#
#         away_diff_passes_accurate  home_diff_passes_percentage  \
# id
# 251711                       <NA>                          NaN
# 849                          <NA>                          NaN
#
#         away_diff_passes_percentage  home_diff_attacks_attacks  \
# id
# 251711                          NaN                         13
# 849                             NaN                          4
#
#         away_diff_attacks_attacks  home_diff_attacks_dangerous_attacks  \
# id
# 251711                        -13                                    6
# 849                            -4                                   -3
#
#         away_diff_attacks_dangerous_attacks
# id
# 251711                                   -6
# 849                                       3

# %%
# Mask home teams 
stats_home = rename_columns_to_team(mask_stats.loc[:, ['time_starting_at_date', 'league_is_cup'] + mask_stats.filter(regex='^home').columns.tolist()])
# Mask away teams 
stats_away = rename_columns_to_team(mask_stats.loc[:, ['time_starting_at_date', 'league_is_cup'] + mask_stats.filter(regex='^away').columns.tolist()])
# Concatenate vertically stats_home and stats_away (avoided problem of using separate home and away IDs by using a team ID)
mask_stats_team = pd.concat([stats_home, stats_away], ignore_index=True).sort_values('time_starting_at_date').reset_index(drop=True)
print(mask_stats_team.shape)
mask_stats_team.tail(2)
# Out:
# (24724, 43)
#       time_starting_at_date  league_is_cup  team_id  team_shots_total  \
# 24722            2022-04-15              0      485                 9
# 24723            2022-04-15              0     6789                12
#
#        team_shots_ongoal  team_shots_offgoal  team_shots_blocked  \
# 24722                  2                   7                   1
# 24723                  4                   8                   1
#
#        team_shots_insidebox  team_shots_outsidebox  team_fouls  team_corners  \
# 24722                     3                      6           7             1
# 24723                     9                      3          15             0
#
#        team_offsides  team_possessiontime  team_yellowcards  team_redcards  \
# 24722              3                   43                 4              0
# 24723              1                   36                 3              0
#
#        team_yellowredcards  team_saves  team_tackles  team_passes_total  \
# 24722                    0           2            26                377
# 24723                    0           2            13                383
#
#        team_passes_accurate  team_passes_percentage  team_attacks_attacks  \
# 24722                   305                    80.9                    95
# 24723                   293                    76.5                    74
#
#        team_attacks_dangerous_attacks  team_diff_shots_total  \
# 24722                              37                     -1
# 24723                              33                     -2
#
#        team_diff_shots_ongoal  team_diff_shots_offgoal  \
# 24722                      -1                        0
# 24723                       0                       -2
#
#        team_diff_shots_blocked  team_diff_shots_insidebox  \
# 24722                        0                         -4
# 24723                       -2                          2
#
#        team_diff_shots_outsidebox  team_diff_fouls  team_diff_corners  \
# 24722                           4              -10                 -7
# 24723                          -3                9                 -6
#
#        team_diff_offsides  team_diff_possessiontime  team_diff_yellowcards  \
# 24722                  -4                       -14                      1
# 24723                   1                       -28                      2
#
#        team_diff_redcards  team_diff_yellowredcards  team_diff_saves  \
# 24722                  -1                        -1                0
# 24723                   0                         0                1
#
#        team_diff_tackles  team_diff_passes_total  team_diff_passes_accurate  \
# 24722                 10                    -100                       -103
# 24723                  4                    -285                       -276
#
#        team_diff_passes_percentage  team_diff_attacks_attacks  \
# 24722                        -4.63                        -13
# 24723                        -8.68                        -51
#
#        team_diff_attacks_dangerous_attacks
# 24722                                  -41
# 24723                                  -25

# %% [markdown]
# Only Home & Only Away data

# %%
list_number_games = [1, 3, 5, 10, 15, 20] # List of n. games to consider

# %%
l_features = mask_stats.loc[:,'home_shots_total':'home_shots_outsidebox'].columns.tolist() # list of features
# Only home and away. Contrary to the form case, there is no distinction between with cups data and without (cups are excluded)
mask_stats = avg_nan_new_features(df=mask_stats, list_features=l_features, list_n_games=list_number_games)
# Print some info
print(mask_stats.shape)
mask_stats.head(3)
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]
# (12362, 102)
#         home_id  away_id time_starting_at_date  league_is_cup  \
# id
# 251711      690      591            2015-08-07              0
# 849          14        6            2015-08-08              0
# 864          33       51            2015-08-08              0
#
#         home_shots_total  home_shots_ongoal  home_shots_offgoal  \
# id
# 251711                12                  2                   0
# 849                    9                  1                   0
# 864                   17                  6                   0
#
#         home_shots_blocked  home_shots_insidebox  home_shots_outsidebox  \
# id
# 251711                   0                     0                      0
# 849                      0                     0                      0
# 864                      0                     0                      0
#
#         home_fouls  home_corners  home_offsides  home_possessiontime  \
# id
# 251711          20             3              0                   52
# 849             12             1              1                   50
# 864             14             1              4                   63
#
#         home_yellowcards  home_redcards  home_yellowredcards  home_saves  \
# id
# 251711                 3              0                    0           1
# 849                    2              0                    0           4
# 864                    1              0                    0           4
#
#         home_tackles  away_shots_total  away_shots_ongoal  away_shots_offgoal  \
# id
# 251711            16                 7                  2                   0
# 849               17                 9                  4                   0
# 864               15                11                  7                   0
#
#         away_shots_blocked  away_shots_insidebox  away_shots_outsidebox  \
# id
# 251711                   0                     0                      0
# 849                      0                     0                      0
# 864                      0                     0                      0
#
#         away_fouls  away_corners  away_offsides  away_possessiontime  \
# id
# 251711          17             2              2                   48
# 849             12             2              2                   50
# 864             20             4              2                   37
#
#         away_yellowcards  away_redcards  away_yellowredcards  away_saves  \
# id
# 251711                 2              1                    0           2
# 849                    3              0                    0           1
# 864                    0              0                    0           5
#
#         away_tackles  home_passes_total  home_passes_accurate  \
# id
# 251711            17               <NA>                  <NA>
# 849               17               <NA>                  <NA>
# 864               18               <NA>                  <NA>
#
#         home_passes_percentage  away_passes_total  away_passes_accurate  \
# id
# 251711                     NaN               <NA>                  <NA>
# 849                        NaN               <NA>                  <NA>
# 864                        NaN               <NA>                  <NA>
#
#         away_passes_percentage  home_attacks_attacks  \
# id
# 251711                     NaN                   106
# 849                        NaN                   100
# 864                        NaN                   114
#
#         home_attacks_dangerous_attacks  away_attacks_attacks  \
# id
# 251711                              48                    93
# 849                                 45                    96
# 864                                 58                   100
#
#         away_attacks_dangerous_attacks  home_diff_shots_total  \
# id
# 251711                              42                      5
# 849                                 48                      0
# 864                                 54                      6
#
#         away_diff_shots_total  home_diff_shots_ongoal  away_diff_shots_ongoal  \
# id
# 251711                     -5                       0                       0
# 849                         0                      -3                       3
# 864                        -6                      -1                       1
#
#         home_diff_shots_offgoal  away_diff_shots_offgoal  \
# id
# 251711                        0                        0
# 849                           0                        0
# 864                           0                        0
#
#         home_diff_shots_blocked  away_diff_shots_blocked  \
# id
# 251711                        0                        0
# 849                           0                        0
# 864                           0                        0
#
#         home_diff_shots_insidebox  away_diff_shots_insidebox  \
# id
# 251711                          0                          0
# 849                             0                          0
# 864                             0                          0
#
#         home_diff_shots_outsidebox  away_diff_shots_outsidebox  \
# id
# 251711                           0                           0
# 849                              0                           0
# 864                              0                           0
#
#         home_diff_fouls  away_diff_fouls  home_diff_corners  \
# id
# 251711                3               -3                  1
# 849                   0                0                 -1
# 864                  -6                6                 -3
#
#         away_diff_corners  home_diff_offsides  away_diff_offsides  \
# id
# 251711                 -1                  -2                   2
# 849                     1                  -1                   1
# 864                     3                   2                  -2
#
#         home_diff_possessiontime  away_diff_possessiontime  \
# id
# 251711                         4                        -4
# 849                            0                         0
# 864                           26                       -26
#
#         home_diff_yellowcards  away_diff_yellowcards  home_diff_redcards  \
# id
# 251711                      1                     -1                  -1
# 849                        -1                      1                   0
# 864                         1                     -1                   0
#
#         away_diff_redcards  home_diff_yellowredcards  \
# id
# 251711                   1                         0
# 849                      0                         0
# 864                      0                         0
#
#         away_diff_yellowredcards  home_diff_saves  away_diff_saves  \
# id
# 251711                         0               -1                1
# 849                            0                3               -3
# 864                            0               -1                1
#
#         home_diff_tackles  away_diff_tackles  home_diff_passes_total  \
# id
# 251711                 -1                  1                    <NA>
# 849                     0                  0                    <NA>
# 864                    -3                  3                    <NA>
#
#         away_diff_passes_total  home_diff_passes_accurate  \
# id
# 251711                    <NA>                       <NA>
# 849                       <NA>                       <NA>
# 864                       <NA>                       <NA>
#
#         away_diff_passes_accurate  home_diff_passes_percentage  \
# id
# 251711                       <NA>                          NaN
# 849                          <NA>                          NaN
# 864                          <NA>                          NaN
#
#         away_diff_passes_percentage  home_diff_attacks_attacks  \
# id
# 251711                          NaN                         13
# 849                             NaN                          4
# 864                             NaN                         14
#
#         away_diff_attacks_attacks  home_diff_attacks_dangerous_attacks  \
# id
# 251711                        -13                                    6
# 849                            -4                                   -3
# 864                           -14                                    4
#
#         away_diff_attacks_dangerous_attacks home_shots_total_last1_games  \
# id
# 251711                                   -6                         <NA>
# 849                                       3                         <NA>
# 864                                      -4                         <NA>
#
#        home_shots_total_last3_games home_shots_total_last5_games  \
# id
# 251711                         <NA>                         <NA>
# 849                            <NA>                         <NA>
# 864                            <NA>                         <NA>
#
#        home_shots_ongoal_last1_games home_shots_ongoal_last3_games  \
# id
# 251711                          <NA>                          <NA>
# 849                             <NA>                          <NA>
# 864                             <NA>                          <NA>
#
#        home_shots_ongoal_last5_games home_shots_offgoal_last1_games  \
# id
# 251711                          <NA>                           <NA>
# 849                             <NA>                           <NA>
# 864                             <NA>                           <NA>
#
#        home_shots_offgoal_last3_games home_shots_offgoal_last5_games  \
# id
# 251711                           <NA>                           <NA>
# 849                              <NA>                           <NA>
# 864                              <NA>                           <NA>
#
#        home_shots_blocked_last1_games home_shots_blocked_last3_games  \
# id
# 251711                           <NA>                           <NA>
# 849                              <NA>                           <NA>
# 864                              <NA>                           <NA>
#
#        home_shots_blocked_last5_games home_shots_insidebox_last1_games  \
# id
# 251711                           <NA>                             <NA>
# 849                              <NA>                             <NA>
# 864                              <NA>                             <NA>
#
#        home_shots_insidebox_last3_games home_shots_insidebox_last5_games  \
# id
# 251711                             <NA>                             <NA>
# 849                                <NA>                             <NA>
# 864                                <NA>                             <NA>
#
#        home_shots_outsidebox_last1_games home_shots_outsidebox_last3_games  \
# id
# 251711                              <NA>                              <NA>
# 849                                 <NA>                              <NA>
# 864                                 <NA>                              <NA>
#
#        home_shots_outsidebox_last5_games
# id
# 251711                              <NA>
# 849                                 <NA>
# 864                                 <NA>

# %% [markdown]
# Both Home & Away data

# %%
l_features2 = mask_stats_team.loc[:,'team_shots_total':].columns.tolist() # list of features
# Both home and away. Contrary to the form case, there is no distinction between with cups data and without (cups are excluded)
mask_stats_team = avg_nan_new_features(df=mask_stats_team, list_features=l_features2, list_n_games=list_number_games)
# Print some info
print(mask_stats_team.shape)
mask_stats_team.head(3)
# Out:
#   0%|          | 0/120 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/xr/y1bkzkl93sl5hxsn03468vzh0000gn/T/ipykernel_68313/1394484757.py in <module>
#       1 l_features2 = mask_stats_team.loc[:,'team_shots_total':].columns.tolist() # list of features
#       2 # Both home and away. Contrary to the form case, there is no distinction between with cups data and without (cups are excluded)
# ----> 3 mask_stats_team = avg_nan_new_features(df=mask_stats_team, list_features=l_features2, list_n_games=list_number_games)
#       4 # Print some info
#       5 print(mask_stats_team.shape)
#
# /var/folders/xr/y1bkzkl93sl5hxsn03468vzh0000gn/T/ipykernel_68313/1411699216.py in avg_nan_new_features(df, list_features, list_n_games, suffix_new_columns)
#      27         # Apply avg_value_n_closest_dates by row
#      28         df.loc[:, elem[0] + '_last' + str(elem[1]) + '_games' + suffix_new_columns] = df.apply(lambda x: avg_value_nan_closest_dates(\
# ---> 29                 df = df.loc[((x[team_id] == df[team_id]) & (x['time_starting_at_date'] > df['time_starting_at_date'])), :], date_col = 'time_starting_at_date', value_col = elem[0], n_size=elem[1]), axis=1)
#      30
#      31     return df
#
# /Library/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# /Library/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# /Library/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# /Library/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# /var/folders/xr/y1bkzkl93sl5hxsn03468vzh0000gn/T/ipykernel_68313/1411699216.py in <lambda>(x)
#      27         # Apply avg_value_n_closest_dates by row
#      28         df.loc[:, elem[0] + '_last' + str(elem[1]) + '_games' + suffix_new_columns] = df.apply(lambda x: avg_value_nan_closest_dates(\
# ---> 29                 df = df.loc[((x[team_id] == df[team_id]) & (x['time_starting_at_date'] > df['time_starting_at_date'])), :], date_col = 'time_starting_at_date', value_col = elem[0], n_size=elem[1]), axis=1)
#      30
#      31     return df
#
# /Library/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /Library/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# /Library/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
#     804                 continue
#     805
# --> 806             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     807             # We should never have retval.ndim < self.ndim, as that should
#     808             #  be handled by the _getitem_lowerdim call above.
#
# /Library/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1142             return self._get_slice_axis(key, axis=axis)
#    1143         elif com.is_bool_indexer(key):
# -> 1144             return self._getbool_axis(key, axis=axis)
#    1145         elif is_list_like_indexer(key):
#    1146
#
# /Library/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getbool_axis(self, key, axis)
#     948         key = check_bool_indexer(labels, key)
#     949         inds = key.nonzero()[0]
# --> 950         return self.obj._take_with_is_copy(inds, axis=axis)
#     951
#     952
#
# /Library/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _take_with_is_copy(self, indices, axis)
#    3626         See the docstring of `take` for full explanation of the parameters.
#    3627         """
# -> 3628         result = self.take(indices=indices, axis=axis)
#    3629         # Maybe set copy if we didn't actually change the index.
#    3630         if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# /Library/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3614
#    3615         new_data = self._mgr.take(
# -> 3616             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3617         )
#    3618         return self._constructor(new_data).__finalize__(self, method="take")
#
# /Library/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify)
#     868             axis=axis,
#     869             allow_dups=True,
# --> 870             consolidate=False,
#     871         )
#     872
#
# /Library/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#     686                     ),
#     687                 )
# --> 688                 for blk in self.blocks
#     689             ]
#     690
#
# /Library/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#     686                     ),
#     687                 )
# --> 688                 for blk in self.blocks
#     689             ]
#     690
#
# /Library/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1155             return self.make_block(new_values, new_mgr_locs)
#    1156         else:
# -> 1157             return self.make_block_same_class(new_values, new_mgr_locs)
#    1158
#    1159     def diff(self, n: int, axis: int = 1) -> list[Block]:
#
# /Library/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in make_block_same_class(self, values, placement)
#     267             placement = self._mgr_locs
#     268
# --> 269         if values.dtype.kind in ["m", "M"]:
#     270             # TODO: remove this once fastparquet has stopped relying on it
#     271             values = ensure_wrapped_if_datetimelike(values)
#
# KeyboardInterrupt:

# %% [markdown]
# Merge only home & away data with both home & away data

# %%
# Merge mask_stats which contains already separated home & away data with mask_stats_teams which has not yet be partitioned in home and away.
# By merging on home_id and date we create before columns for home (defined using home_ prefix)
mask_stats_with_only_home_teams = pd.merge(mask_stats.reset_index(), mask_stats_team.add_prefix('home_'), how='left', \
    left_on=['home_id', 'time_starting_at_date'], right_on=['home_team_id', 'home_time_starting_at_date']) # on home_id
# By merging on away_id and date we create before columns for away (defined using away_ prefix)
mask_stats_complete = pd.merge(mask_stats_with_only_home_teams, mask_stats_team.add_prefix('away_'), how='left', \
    left_on=['away_id', 'time_starting_at_date'], right_on=['away_team_id', 'away_time_starting_at_date']) # on_away
mask_stats_complete = mask_stats_complete[mask_stats_complete['time_starting_at_date'] > '2016-06-06'].set_index('id')
mask_stats_complete.head()

# %%
mask_stats_complete.to_csv('../../Data/Modeling_Before_Preparation/Stats_data_v01.csv')
